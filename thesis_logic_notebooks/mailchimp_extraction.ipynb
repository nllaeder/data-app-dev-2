# %% [markdown]
# # Mailchimp API Authentication and Setup
#
# This section handles the complete authentication and setup process required to interact with the Mailchimp API.
#
# **The process is as follows:**
# 1.  **Import Libraries:** Load necessary Python libraries (`requests`, `json`, `google.cloud.secretmanager`).
# 2.  **Set Configuration:** Define constants for the GCP Project ID and the name of the Mailchimp token secret in Secret Manager.
# 3.  **Retrieve Credentials:**
#     * Connect to Google Cloud Secret Manager.
#     * Fetch the stored secret, which contains a JSON object with the `access_token` and `dc` (server prefix).
# 4.  **Prepare for API Calls:**
#     * Parse the JSON credentials.
#     * Dynamically construct the `API_BASE_URL` using the server prefix.
#     * Create the `headers` dictionary with the Bearer token for authorization.
# 5.  **Connection Test:**
#     * Call the `/ping` endpoint to verify that the credentials and connection are valid. A successful test returns a `200` status code.

# %%
import sys
import requests
import json
from google.cloud import secretmanager # Direct import is fine for notebooks

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# --- Mailchimp Configuration ---
GCP_PROJECT_ID = "mis581-capstone-data"

# The ID of the secret in Secret Manager containing the Mailchimp tokens
# This comes from your successful OAuth flow.
MC_TOKEN_SECRET_NAME = "peer2_mailchimp_token"

print("Mailchimp configuration variables are set.")
# Out:
# Mailchimp configuration variables are set.

# %%
# Initialize clients
secret_client = secretmanager.SecretManagerServiceClient()

try:
    # 1. Fetch the secret's payload
    secret_name = f"projects/{GCP_PROJECT_ID}/secrets/{MC_TOKEN_SECRET_NAME}/versions/latest"
    response = secret_client.access_secret_version(request={"name": secret_name})
    payload = response.payload.data.decode("UTF-8")
    
    # 2. Parse the JSON string from the secret
    credentials = json.loads(payload)
    access_token = credentials.get("access_token")
    server_prefix = credentials.get("dc") # 'dc' is the data center/server prefix

    if not access_token or not server_prefix:
        raise ValueError("'access_token' or 'dc' not found in the secret payload.")

    # 3. Dynamically build the API URL and headers
    API_BASE_URL = f"https://{server_prefix}.api.mailchimp.com/3.0"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    
    print("Successfully retrieved Mailchimp credentials and prepared API details.")
    print(f"API Base URL configured for server prefix: {server_prefix}")

except Exception as e:
    print(f"An error occurred during setup: {e}")
    # Set to None to prevent subsequent cells from running with bad data
    API_BASE_URL = None
# Out:
# Successfully retrieved Mailchimp credentials and prepared API details.
# API Base URL configured for server prefix: us18

# %%
if API_BASE_URL:
    # Use the /ping endpoint for a simple health check
    test_endpoint = "/ping"
    full_url = API_BASE_URL + test_endpoint
    
    print(f"Making a test API call to: {full_url}")
    
    try:
        response = requests.get(full_url, headers=headers, timeout=10)
        print("API call sent successfully. Check the next cell for the response.")
        
    except requests.exceptions.RequestException as e:
        print(f"An error occurred during the API request: {e}")
        response = None
else:
    print("Cannot make API call, setup in the previous cell failed.")
    response = None
# Out:
# Making a test API call to: https://us18.api.mailchimp.com/3.0/ping
# API call sent successfully. Check the next cell for the response.

# %%
if response:
    print(f"HTTP Status Code: {response.status_code}")
    
    if response.status_code == 200:
        print("\nSUCCESS! The API call to Mailchimp worked.")
        print("Here is the response from the server:")
        # Pretty-print the JSON response
        print(json.dumps(response.json(), indent=2))
    else:
        print("\nERROR: The API call failed.")
        print("Here is the error response:")
        # Print the raw text of the error
        print(response.text)
else:
    print("Response object is None. The API call likely did not complete.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 if response:
# ----> 2     print(f"HTTP Status Code: {response.status_code}")
#       4     if response.status_code == 200:
#       5         print("\nSUCCESS! The API call to Mailchimp worked.")
#
# File /opt/conda/envs/mis581/lib/python3.12/site-packages/proto/message.py:877, in Message.__getattr__(self, key)
#     875 (key, pb_type) = self._get_pb_type_from_key(key)
#     876 if pb_type is None:
# --> 877     raise AttributeError(
#     878         "Unknown field for {}: {}".format(self.__class__.__name__, key)
#     879     )
#     880 pb_value = getattr(self._pb, key)
#     881 marshal = self._meta.marshal
#
# AttributeError: Unknown field for AccessSecretVersionResponse: status_code

# %% [markdown]
# # Data Extraction from Mailchimp API
#
# Now that authentication is successful, this section focuses on the primary goal: extracting marketing data from Mailchimp endpoints and preparing it for loading into Google BigQuery.
#
# ### Part 1: Fetching List Members
#
# The first step is to download all contacts (list members) from the primary audience.
#
# **The process is as follows:**
# 1.  **Define Extraction Function:** Create a Python function (`fetch_all_mailchimp_members`) that takes the API credentials and a `list_id` as input.
# 2.  **Handle Pagination:** Inside the function, implement a `while` loop to repeatedly call the API, using the `offset` and `count` parameters to navigate through all pages of results until no more members are returned.
# 3.  **Execute Fetch:** Call the function to retrieve the complete list of all members.
# 4.  **Structure for BigQuery:**
#     * Loop through the raw list of members returned from the API.
#     * For each member, create a dictionary with two keys:
#         * `raw_data`: A JSON string of the complete, unaltered member record.
#         * [cite_start]`tenant_id`: A string identifier for the data source (e.g., 'peer2') to support multi-tenancy[cite: 152, 161, 167, 174].
# 5.  [cite_start]**Load to BigQuery:** Pass the final list of structured records to a loading function that writes them to the appropriate raw data table (e.g., `peer2_mailchimp_members_raw`)[cite: 128, 154, 168].

# %%
import json
import requests
from google.cloud import secretmanager

# ===================================================================
#                      CONFIGURATION
# ===================================================================
GCP_PROJECT_ID = "mis581-capstone-data"
MC_TOKEN_SECRET_NAME = "peer2_mailchimp_token"

print("--- Step 1: Authenticating with Google and Mailchimp ---")

# ===================================================================
#                      AUTHENTICATION LOGIC
# ===================================================================
try:
    # Initialize Google Cloud client
    secret_client = secretmanager.SecretManagerServiceClient()
    
    # Use a specific variable name for the secret manager response
    secret_name = f"projects/{GCP_PROJECT_ID}/secrets/{MC_TOKEN_SECRET_NAME}/versions/latest"
    secret_response = secret_client.access_secret_version(request={"name": secret_name})
    
    # Decode the payload from the specific secret_response object
    payload = secret_response.payload.data.decode("UTF-8")
    
    credentials = json.loads(payload)
    access_token = credentials.get("access_token")
    server_prefix = credentials.get("dc")

    if not access_token or not server_prefix:
        raise ValueError("'access_token' or 'dc' not found in the secret payload.")

    API_BASE_URL = f"https://{server_prefix}.api.mailchimp.com/3.0"
    headers = { "Authorization": f"Bearer {access_token}" }
    
    print("Authentication successful. Prepared API details.")
    print(f"API Base URL configured for server prefix: {server_prefix}")

except Exception as e:
    API_BASE_URL = None
    headers = None
    print(f"!!! An error occurred during the AUTHENTICATION phase: {e}")

# ===================================================================
#                 FETCH ALL LISTS (AUDIENCES)
# ===================================================================
# This part only runs if authentication was successful
if API_BASE_URL and headers:
    print("\n--- Step 2: Fetching all Mailchimp Lists (Audiences) ---")
    
    endpoint = "/lists"
    full_url = API_BASE_URL + endpoint

    try:
        # Use a specific variable name for the Mailchimp API response
        mc_response = requests.get(full_url, headers=headers, timeout=15)
        mc_response.raise_for_status() # Check for HTTP errors
        
        mailchimp_lists_data = mc_response.json()
        print("\nSUCCESS: API call was successful.")
        
        lists_found = mailchimp_lists_data.get('lists', [])
        if lists_found:
            print(f"Found {len(lists_found)} list(s) in the account:")
            for list_item in lists_found:
                print(f"  - List Name: \"{list_item.get('name')}\", ID: {list_item.get('id')}")
        else:
            print("No lists (audiences) were found in this Mailchimp account.")

    except requests.exceptions.HTTPError as e:
        print(f"\nERROR: The API call to Mailchimp failed with status code {e.response.status_code}.")
        print(f"Response Body: {e.response.text}")
    except Exception as e:
        print(f"An unexpected error occurred while fetching lists: {e}")
# Out:
# --- Step 1: Authenticating with Google and Mailchimp ---
# Authentication successful. Prepared API details.
# API Base URL configured for server prefix: us18
#
# --- Step 2: Fetching all Mailchimp Lists (Audiences) ---
#
# SUCCESS: API call was successful.
# Found 10 list(s) in the account:
#   - List Name: "2023-2024 Free Trials Musikgarten, Music Immersion, Pre-Instruments", ID: 0178eb30f5
#   - List Name: "Current Private Lessons Students 2024-2025", ID: 1477246008
#   - List Name: "Summer Camps 2024", ID: 3b93b1512e
#   - List Name: "Musikgarten and Music Immersion Enrollment 2019-2023", ID: 555a29bd42
#   - List Name: "Private Lessons- All Time", ID: 5c021fd130
#   - List Name: "Current Private Lessons Students 2023-2024", ID: 6fa6cd3238
#   - List Name: "Spring 2023 Students", ID: 8bbe106a9f
#   - List Name: "Winter 2024 Students", ID: 98395f51cf
#   - List Name: "Free Trials December 2022-February 2023", ID: 9d6561c536
#   - List Name: "Free Trials - Musikgarten, Music Immersion, and Pre-Instruments March - August 2024", ID: 9f1c819f2a

# %%
import json
import requests
import time
from google.cloud import secretmanager

# ===================================================================
#                      1. CONFIGURATION
# ===================================================================
GCP_PROJECT_ID = "mis581-capstone-data"
MC_TOKEN_SECRET_NAME = "peer2_mailchimp_token"
print("Configuration set.")

# ===================================================================
#                      2. AUTHENTICATION
# ===================================================================
print("\n--- Authenticating with Google and Mailchimp ---")
try:
    # THIS LINE IS NOW CORRECTED
    secret_client = secretmanager.SecretManagerServiceClient()
    
    secret_name = f"projects/{GCP_PROJECT_ID}/secrets/{MC_TOKEN_SECRET_NAME}/versions/latest"
    secret_response = secret_client.access_secret_version(request={"name": secret_name})
    payload = secret_response.payload.data.decode("UTF-8")
    
    credentials = json.loads(payload)
    mc_access_token = credentials.get("access_token")
    mc_server_prefix = credentials.get("dc")

    if not mc_access_token or not mc_server_prefix:
        raise ValueError("'access_token' or 'dc' not found in the secret payload.")

    API_BASE_URL = f"https://{mc_server_prefix}.api.mailchimp.com/3.0"
    headers = { "Authorization": f"Bearer {mc_access_token}" }
    
    print("Authentication successful.")
except Exception as e:
    API_BASE_URL = None
    print(f"!!! An error occurred during the AUTHENTICATION phase: {e}")

# ===================================================================
#           3. FUNCTION DEFINITION FOR FETCHING MEMBERS
# ===================================================================
def fetch_all_mailchimp_members(token, server_prefix, list_id):
    """Fetches all members from a Mailchimp list, handling pagination."""
    all_members = []
    page_size = 200
    offset = 0
    
    api_url = f"https://{server_prefix}.api.mailchimp.com/3.0/lists/{list_id}/members"
    auth_headers = {"Authorization": f"Bearer {token}"}

    while True:
        params = {"count": page_size, "offset": offset}
        try:
            response = requests.get(api_url, headers=auth_headers, params=params)
            response.raise_for_status()
            data = response.json()
            
            members = data.get('members', [])
            if not members: break
            
            all_members.extend(members)
            print(f"  Fetched {len(members)} members, total for this list so far: {len(all_members)}")
            
            offset += page_size
            time.sleep(0.5)
        except requests.exceptions.HTTPError as e:
            print(f"  !!! HTTP Error fetching members: {e}")
            break
            
    return all_members

# ===================================================================
#                   4. MAIN EXECUTION LOGIC
# ===================================================================
# This logic only runs if authentication was successful
if API_BASE_URL:
    print("\n--- Fetching all Mailchimp Lists (Audiences) ---")
    try:
        mc_response = requests.get(f"{API_BASE_URL}/lists", headers=headers, timeout=15)
        mc_response.raise_for_status()
        lists_found = mc_response.json().get('lists', [])
        
        if lists_found:
            print(f"Found {len(lists_found)} list(s). Now fetching members from each.")
            
            # This dictionary will hold all the final data
            all_data = {}
            
            for list_item in lists_found:
                list_id = list_item.get('id')
                list_name = list_item.get('name')
                print(f"\nProcessing List: \"{list_name}\" (ID: {list_id})")
                
                # Fetch all members for the current list_id
                members_of_list = fetch_all_mailchimp_members(mc_access_token, mc_server_prefix, list_id)
                
                all_data[list_id] = {
                    "name": list_name,
                    "members": members_of_list,
                    "member_count": len(members_of_list)
                }
                print(f"-> Finished \"{list_name}\". Found {len(members_of_list)} members.")
            
            print("\n\n--- ALL DATA EXTRACTION COMPLETE ---")
            total_members = sum(d['member_count'] for d in all_data.values())
            print(f"Successfully fetched a grand total of {total_members} members across {len(all_data)} lists.")
            # The 'all_data' variable now holds all your contact information.
            
        else:
            print("No lists (audiences) were found in this Mailchimp account.")
            
    except Exception as e:
        print(f"An unexpected error occurred during the main execution: {e}")
# Out:
# Configuration set.
#
# --- Authenticating with Google and Mailchimp ---
# Authentication successful.
#
# --- Fetching all Mailchimp Lists (Audiences) ---
# Found 10 list(s). Now fetching members from each.
#
# Processing List: "2023-2024 Free Trials Musikgarten, Music Immersion, Pre-Instruments" (ID: 0178eb30f5)
#   Fetched 105 members, total for this list so far: 105
# -> Finished "2023-2024 Free Trials Musikgarten, Music Immersion, Pre-Instruments". Found 105 members.
#
# Processing List: "Current Private Lessons Students 2024-2025" (ID: 1477246008)
#   Fetched 183 members, total for this list so far: 183
# -> Finished "Current Private Lessons Students 2024-2025". Found 183 members.
#
# Processing List: "Summer Camps 2024" (ID: 3b93b1512e)
#   Fetched 200 members, total for this list so far: 200
#   Fetched 200 members, total for this list so far: 400
#   Fetched 62 members, total for this list so far: 462
# -> Finished "Summer Camps 2024". Found 462 members.
#
# Processing List: "Musikgarten and Music Immersion Enrollment 2019-2023" (ID: 555a29bd42)
#   Fetched 200 members, total for this list so far: 200
#   Fetched 200 members, total for this list so far: 400
#   Fetched 89 members, total for this list so far: 489
# -> Finished "Musikgarten and Music Immersion Enrollment 2019-2023". Found 489 members.
#
# Processing List: "Private Lessons- All Time" (ID: 5c021fd130)
#   Fetched 200 members, total for this list so far: 200
#   Fetched 200 members, total for this list so far: 400
#   Fetched 161 members, total for this list so far: 561
# -> Finished "Private Lessons- All Time". Found 561 members.
#
# Processing List: "Current Private Lessons Students 2023-2024" (ID: 6fa6cd3238)
#   Fetched 200 members, total for this list so far: 200
#   Fetched 50 members, total for this list so far: 250
# -> Finished "Current Private Lessons Students 2023-2024". Found 250 members.
#
# Processing List: "Spring 2023 Students" (ID: 8bbe106a9f)
#   Fetched 200 members, total for this list so far: 200
#   Fetched 200 members, total for this list so far: 400
#   Fetched 200 members, total for this list so far: 600
#   Fetched 200 members, total for this list so far: 800
#   Fetched 48 members, total for this list so far: 848
# -> Finished "Spring 2023 Students". Found 848 members.
#
# Processing List: "Winter 2024 Students" (ID: 98395f51cf)
#   Fetched 200 members, total for this list so far: 200
#   Fetched 200 members, total for this list so far: 400
#   Fetched 200 members, total for this list so far: 600
#   Fetched 200 members, total for this list so far: 800
#   Fetched 200 members, total for this list so far: 1000
#   Fetched 78 members, total for this list so far: 1078
# -> Finished "Winter 2024 Students". Found 1078 members.
#
# Processing List: "Free Trials December 2022-February 2023" (ID: 9d6561c536)
#   Fetched 89 members, total for this list so far: 89
# -> Finished "Free Trials December 2022-February 2023". Found 89 members.
#
# Processing List: "Free Trials - Musikgarten, Music Immersion, and Pre-Instruments March - August 2024" (ID: 9f1c819f2a)
# -> Finished "Free Trials - Musikgarten, Music Immersion, and Pre-Instruments March - August 2024". Found 0 members.
#
#
# --- ALL DATA EXTRACTION COMPLETE ---
# Successfully fetched a grand total of 4065 members across 10 lists.

# %%
import json
from google.cloud import bigquery

# ===================================================================
#                      CONFIGURATION
# ===================================================================
TENANT_ID = "peer2"
BIGQUERY_PROJECT_ID = "mis581-capstone-data"
BIGQUERY_TABLE_ID = f"{BIGQUERY_PROJECT_ID}.raw_data.peer2_members_raw"
print("Configuration for BigQuery load is set.")

# ===================================================================
#                BIGQUERY LOADING UTILITY FUNCTION
# ===================================================================
def load_data_to_bigquery(table_id, data_list):
    """Loads a list of dictionary records into the specified BigQuery table."""
    if not data_list:
        print("No data to load.")
        return

    bq_client = bigquery.Client(project=BIGQUERY_PROJECT_ID)
    
    job_config = bigquery.LoadJobConfig(
        schema=[
            bigquery.SchemaField("raw_data", "STRING"),
            bigquery.SchemaField("tenant_id", "STRING"),
        ],
        # If your raw_data column is JSON type in BQ, use WRITE_TRUNCATE or WRITE_APPEND
        write_disposition="WRITE_TRUNCATE", # This will overwrite the table
    )
    
    print(f"Initiating load job for {len(data_list)} records into {table_id}...")
    load_job = bq_client.load_table_from_json(data_list, table_id, job_config=job_config)
    load_job.result() # Wait for the job to complete
    
    print(f"SUCCESS: BigQuery load job finished for table {table_id}.")
    print(f"Loaded {load_job.output_rows} rows.")

# ===================================================================
#                         MAIN EXECUTION
# ===================================================================
# Check if the 'all_data' variable from the previous cell exists.
if 'all_data' in globals() and all_data:
    # Step 1: Flatten the data from the dictionary into a single list of members.
    all_members_flat_list = []
    for list_id in all_data:
        all_members_flat_list.extend(all_data[list_id]['members'])
    
    # THIS IS THE CORRECTED LOGIC:
    # First, we confirm we have a list, then we use ITS length.
    if all_members_flat_list:
        print(f"\n--- Preparing {len(all_members_flat_list)} records for BigQuery load ---")

        # [cite_start]Step 2: Structure the data for BigQuery loading. [cite: 61, 78, 99, 123]
        records_to_load = []
        for member in all_members_flat_list:
            record = {
                "raw_data": json.dumps(member),
                "tenant_id": TENANT_ID
            }
            records_to_load.append(record)
        
        # [cite_start]Step 3: Load the prepared data into BigQuery. [cite: 5, 117, 159, 164]
        try:
            load_data_to_bigquery(BIGQUERY_TABLE_ID, records_to_load)
        except Exception as e:
            print(f"!!! An error occurred during the BigQuery load job: {e}")
    else:
        print("--- Flattened data list is empty. Nothing to load. ---")
else:
    print("!!! ERROR: Could not find the 'all_data' variable. Please re-run the previous extraction cell first. !!!")
# Out:
# Configuration for BigQuery load is set.
#
# --- Preparing 4065 records for BigQuery load ---
# Initiating load job for 4065 records into mis581-capstone-data.raw_data.peer2_members_raw...
# SUCCESS: BigQuery load job finished for table mis581-capstone-data.raw_data.peer2_members_raw.
# Loaded 4065 rows.

# %%
import json
import requests
import time
from google.cloud import secretmanager
from google.cloud import bigquery

# ===================================================================
#                      1. CONFIGURATION
# ===================================================================
GCP_PROJECT_ID = "mis581-capstone-data"
MC_TOKEN_SECRET_NAME = "peer2_mailchimp_token"
TENANT_ID = "peer2"
BIGQUERY_CAMPAIGNS_TABLE_ID = f"{GCP_PROJECT_ID}.raw_data.peer2_campaigns_raw"
print("Configuration set for Campaign extraction.")

# ===================================================================
#                      2. AUTHENTICATION
# ===================================================================
print("\n--- Authenticating with Google and Mailchimp ---")
try:
    secret_client = secretmanager.SecretManagerServiceClient()
    secret_name = f"projects/{GCP_PROJECT_ID}/secrets/{MC_TOKEN_SECRET_NAME}/versions/latest"
    secret_response = secret_client.access_secret_version(request={"name": secret_name})
    payload = secret_response.payload.data.decode("UTF-8")
    
    credentials = json.loads(payload)
    mc_access_token = credentials.get("access_token")
    mc_server_prefix = credentials.get("dc")

    if not mc_access_token or not mc_server_prefix:
        raise ValueError("'access_token' or 'dc' not found in the secret payload.")

    API_BASE_URL = f"https://{mc_server_prefix}.api.mailchimp.com/3.0"
    print("Authentication successful.")
except Exception as e:
    API_BASE_URL = None
    print(f"!!! An error occurred during the AUTHENTICATION phase: {e}")

# ===================================================================
#           3. UTILITY FUNCTIONS (FETCH & LOAD)
# ===================================================================
def fetch_all_mailchimp_campaigns(token, server_prefix):
    """Fetches all campaigns from a Mailchimp account, handling pagination."""
    all_campaigns = []
    page_size = 100
    offset = 0
    
    api_url = f"https://{server_prefix}.api.mailchimp.com/3.0/campaigns"
    auth_headers = {"Authorization": f"Bearer {token}"}

    while True:
        params = {"count": page_size, "offset": offset}
        try:
            response = requests.get(api_url, headers=auth_headers, params=params)
            response.raise_for_status()
            data = response.json()
            
            campaigns = data.get('campaigns', [])
            if not campaigns: break
            
            all_campaigns.extend(campaigns)
            print(f"  Fetched {len(campaigns)} campaigns, total so far: {len(all_campaigns)}")
            
            offset += page_size
            time.sleep(0.5)
        except requests.exceptions.HTTPError as e:
            print(f"  !!! HTTP Error fetching campaigns: {e}")
            break
            
    return all_campaigns

def load_data_to_bigquery(table_id, data_list):
    """Loads a list of dictionary records into the specified BigQuery table."""
    if not data_list:
        print("No data to load.")
        return

    bq_client = bigquery.Client(project=GCP_PROJECT_ID)
    job_config = bigquery.LoadJobConfig(
        schema=[
            bigquery.SchemaField("raw_data", "STRING"),
            bigquery.SchemaField("tenant_id", "STRING"),
        ],
        write_disposition="WRITE_TRUNCATE",
    )
    
    print(f"\nInitiating load job for {len(data_list)} records into {table_id}...")
    load_job = bq_client.load_table_from_json(data_list, table_id, job_config=job_config)
    load_job.result()
    
    print(f"SUCCESS: BigQuery load job finished. Loaded {load_job.output_rows} rows.")

# ===================================================================
#                   4. MAIN EXECUTION LOGIC
# ===================================================================
if API_BASE_URL:
    print("\n--- Starting Mailchimp Campaign Data Extraction ---")
    
    # Step 1: Fetch all campaigns
    all_campaigns = fetch_all_mailchimp_campaigns(mc_access_token, mc_server_prefix)
    
    if all_campaigns:
        print(f"\n--- Extraction Complete: Found {len(all_campaigns)} total campaigns. ---")
        
        # Step 2: Structure data for BigQuery
        records_to_load = []
        for campaign in all_campaigns:
            record = {
                "raw_data": json.dumps(campaign),
                "tenant_id": TENANT_ID
            }
            records_to_load.append(record)

        # Step 3: Load data into BigQuery
        try:
            load_data_to_bigquery(BIGQUERY_CAMPAIGNS_TABLE_ID, records_to_load)
        except Exception as e:
            print(f"!!! An error occurred during the BigQuery load job: {e}")
    else:
        print("No campaigns found in the account.")
else:
    print("Execution halted due to authentication failure.")
# Out:
# Configuration set for Campaign extraction.
#
# --- Authenticating with Google and Mailchimp ---
# Authentication successful.
#
# --- Starting Mailchimp Campaign Data Extraction ---
#   Fetched 100 campaigns, total so far: 100
#   Fetched 100 campaigns, total so far: 200
#   Fetched 100 campaigns, total so far: 300
#   Fetched 100 campaigns, total so far: 400
#   Fetched 100 campaigns, total so far: 500
#   Fetched 100 campaigns, total so far: 600
#   Fetched 100 campaigns, total so far: 700
#   Fetched 100 campaigns, total so far: 800
#   Fetched 100 campaigns, total so far: 900
#   Fetched 100 campaigns, total so far: 1000
#   Fetched 100 campaigns, total so far: 1100
#   Fetched 100 campaigns, total so far: 1200
#   Fetched 100 campaigns, total so far: 1300
#   Fetched 100 campaigns, total so far: 1400
#   Fetched 100 campaigns, total so far: 1500
#   Fetched 100 campaigns, total so far: 1600
#   Fetched 100 campaigns, total so far: 1700
#   Fetched 100 campaigns, total so far: 1800
#   Fetched 100 campaigns, total so far: 1900
#   Fetched 100 campaigns, total so far: 2000
#   Fetched 100 campaigns, total so far: 2100
#   Fetched 60 campaigns, total so far: 2160
#
# --- Extraction Complete: Found 2160 total campaigns. ---
#
# Initiating load job for 2160 records into mis581-capstone-data.raw_data.peer2_campaigns_raw...
# SUCCESS: BigQuery load job finished. Loaded 2160 rows.

# %%
import json
import requests
import time
from google.cloud import secretmanager
from google.cloud import bigquery

# ===================================================================
#                      1. CONFIGURATION
# ===================================================================
GCP_PROJECT_ID = "mis581-capstone-data"
MC_TOKEN_SECRET_NAME = "peer2_mailchimp_token"
TENANT_ID = "peer2"
BIGQUERY_REPORTS_TABLE_ID = f"{GCP_PROJECT_ID}.raw_data.peer2_reports_raw"
print("Configuration set for Campaign Report extraction.")

# ===================================================================
#                      2. AUTHENTICATION
# ===================================================================
print("\n--- Authenticating with Google and Mailchimp ---")
try:
    secret_client = secretmanager.SecretManagerServiceClient()
    secret_name = f"projects/{GCP_PROJECT_ID}/secrets/{MC_TOKEN_SECRET_NAME}/versions/latest"
    secret_response = secret_client.access_secret_version(request={"name": secret_name})
    payload = secret_response.payload.data.decode("UTF-8")
    
    credentials = json.loads(payload)
    mc_access_token = credentials.get("access_token")
    mc_server_prefix = credentials.get("dc")

    if not mc_access_token or not mc_server_prefix:
        raise ValueError("'access_token' or 'dc' not found in the secret payload.")

    API_BASE_URL = f"https://{mc_server_prefix}.api.mailchimp.com/3.0"
    print("Authentication successful.")
except Exception as e:
    API_BASE_URL = None
    print(f"!!! An error occurred during the AUTHENTICATION phase: {e}")

# ===================================================================
#           3. UTILITY FUNCTIONS (FETCH & LOAD)
# ===================================================================
def fetch_all_mailchimp_campaigns(token, server_prefix):
    """Fetches all campaigns from a Mailchimp account, handling pagination."""
    all_campaigns = []
    page_size = 100
    offset = 0
    api_url = f"https://{server_prefix}.api.mailchimp.com/3.0/campaigns"
    auth_headers = {"Authorization": f"Bearer {token}"}
    while True:
        params = {"count": page_size, "offset": offset, "fields": "campaigns.id"} # Only need the ID
        try:
            response = requests.get(api_url, headers=auth_headers, params=params)
            response.raise_for_status()
            data = response.json()
            campaigns = data.get('campaigns', [])
            if not campaigns: break
            all_campaigns.extend(campaigns)
            offset += page_size
        except requests.exceptions.HTTPError as e:
            print(f"  !!! HTTP Error fetching campaigns: {e}")
            break
    return all_campaigns

def fetch_campaign_reports(token, server_prefix, campaigns_list):
    """Loops through campaigns and fetches the report for each one."""
    all_reports = []
    auth_headers = {"Authorization": f"Bearer {token}"}
    
    for i, campaign in enumerate(campaigns_list):
        campaign_id = campaign.get('id')
        if not campaign_id: continue

        print(f"  Fetching report {i+1} of {len(campaigns_list)} for campaign ID: {campaign_id}")
        report_url = f"https://{server_prefix}.api.mailchimp.com/3.0/reports/{campaign_id}"
        
        try:
            response = requests.get(report_url, headers=auth_headers)
            response.raise_for_status()
            report_data = response.json()
            
            # Add the campaign_id to the report data for easier joins later [cite: 110]
            report_data['campaign_id'] = campaign_id
            all_reports.append(report_data)
            time.sleep(0.5) # Be courteous to the API
        except requests.exceptions.HTTPError as e:
            # A 404 error is common for campaigns that have no report data (e.g., drafts)
            if e.response.status_code == 404:
                print(f"    -> No report found for campaign {campaign_id} (Status 404). Skipping.")
            else:
                print(f"    -> HTTP Error for campaign {campaign_id}: {e}")
                
    return all_reports

def load_data_to_bigquery(table_id, data_list):
    """Loads a list of dictionary records into the specified BigQuery table."""
    if not data_list:
        print("No data to load.")
        return

    bq_client = bigquery.Client(project=GCP_PROJECT_ID)
    job_config = bigquery.LoadJobConfig(
        schema=[
            bigquery.SchemaField("raw_data", "STRING"),
            bigquery.SchemaField("tenant_id", "STRING"),
        ],
        write_disposition="WRITE_TRUNCATE",
    )
    
    print(f"\nInitiating load job for {len(data_list)} records into {table_id}...")
    load_job = bq_client.load_table_from_json(data_list, table_id, job_config=job_config)
    load_job.result()
    
    print(f"SUCCESS: BigQuery load job finished. Loaded {load_job.output_rows} rows.")

# ===================================================================
#                   4. MAIN EXECUTION LOGIC
# ===================================================================
if API_BASE_URL:
    print("\n--- Starting Mailchimp Campaign Report Data Extraction ---")
    
    # Step 1: Get a fresh list of all campaign IDs. We only need the ID field.
    print("First, getting a list of all campaign IDs...")
    all_campaigns = fetch_all_mailchimp_campaigns(mc_access_token, mc_server_prefix)
    
    if all_campaigns:
        print(f"Found {len(all_campaigns)} campaigns. Now fetching a report for each.")
        
        # Step 2: Fetch the report for each campaign
        all_reports = fetch_campaign_reports(mc_access_token, mc_server_prefix, all_campaigns)
        
        if all_reports:
            print(f"\n--- Extraction Complete: Found {len(all_reports)} total reports. ---")

            # Step 3: Structure data for BigQuery
            records_to_load = []
            for report in all_reports:
                record = {
                    "raw_data": json.dumps(report),
                    "tenant_id": TENANT_ID
                }
                records_to_load.append(record)

            # Step 4: Load data into BigQuery [cite: 76, 111]
            try:
                load_data_to_bigquery(BIGQUERY_REPORTS_TABLE_ID, records_to_load)
            except Exception as e:
                print(f"!!! An error occurred during the BigQuery load job: {e}")
        else:
            print("No reports were successfully fetched.")
    else:
        print("No campaigns found, cannot fetch reports.")
else:
    print("Execution halted due to authentication failure.")
# Out:
# Configuration set for Campaign Report extraction.
#
# --- Authenticating with Google and Mailchimp ---
# Authentication successful.
#
# --- Starting Mailchimp Campaign Report Data Extraction ---
# First, getting a list of all campaign IDs...
# Found 2160 campaigns. Now fetching a report for each.
#   Fetching report 1 of 2160 for campaign ID: b2fcd2fe98
#   Fetching report 2 of 2160 for campaign ID: 972fb02471
#   Fetching report 3 of 2160 for campaign ID: d7ffb8c76c
#   Fetching report 4 of 2160 for campaign ID: 3daeaccb4e
#   Fetching report 5 of 2160 for campaign ID: 4a46fdddaa
#   Fetching report 6 of 2160 for campaign ID: 4854dd261e
#   Fetching report 7 of 2160 for campaign ID: 38937e2ccb
#   Fetching report 8 of 2160 for campaign ID: 655a59525d
#   Fetching report 9 of 2160 for campaign ID: 1fe1e3df2b
#   Fetching report 10 of 2160 for campaign ID: 4d8be3fbe7
#   Fetching report 11 of 2160 for campaign ID: b5971a5265
#   Fetching report 12 of 2160 for campaign ID: b860727e87
#   Fetching report 13 of 2160 for campaign ID: b85bff1a67
#   Fetching report 14 of 2160 for campaign ID: efcdceae8f
#   Fetching report 15 of 2160 for campaign ID: 8fb701d7e1
#   Fetching report 16 of 2160 for campaign ID: eac6744f9e
#   Fetching report 17 of 2160 for campaign ID: 359dba27ac
#   Fetching report 18 of 2160 for campaign ID: 0d11e6f467
#   Fetching report 19 of 2160 for campaign ID: aba09ec38b
#   Fetching report 20 of 2160 for campaign ID: 139c7468b7
#   Fetching report 21 of 2160 for campaign ID: 7cb5e9568c
#   Fetching report 22 of 2160 for campaign ID: 29831ebf7d
#   Fetching report 23 of 2160 for campaign ID: 8e1f888438
#   Fetching report 24 of 2160 for campaign ID: 11b284039e
#   Fetching report 25 of 2160 for campaign ID: dcda590afe
#   Fetching report 26 of 2160 for campaign ID: 14bba94018
#   Fetching report 27 of 2160 for campaign ID: 91ce97a0ec
#   Fetching report 28 of 2160 for campaign ID: d29102c544
#   Fetching report 29 of 2160 for campaign ID: 8d020253d3
#   Fetching report 30 of 2160 for campaign ID: fa0798d8e6
#   Fetching report 31 of 2160 for campaign ID: 8dbb9bb1c6
#   Fetching report 32 of 2160 for campaign ID: b755d8097d
#   Fetching report 33 of 2160 for campaign ID: aa92ef34a2
#   Fetching report 34 of 2160 for campaign ID: 47372f2f92
#   Fetching report 35 of 2160 for campaign ID: c812e0e8d4
#   Fetching report 36 of 2160 for campaign ID: eebb82873b
#   Fetching report 37 of 2160 for campaign ID: e816e0a463
#   Fetching report 38 of 2160 for campaign ID: 716899d048
#   Fetching report 39 of 2160 for campaign ID: 39d135119d
#   Fetching report 40 of 2160 for campaign ID: 128cf47b75
#   Fetching report 41 of 2160 for campaign ID: 41a3a87a20
#   Fetching report 42 of 2160 for campaign ID: a89f670b61
#   Fetching report 43 of 2160 for campaign ID: e03593099c
#   Fetching report 44 of 2160 for campaign ID: 999dc806d0
#   Fetching report 45 of 2160 for campaign ID: 352806171d
#   Fetching report 46 of 2160 for campaign ID: c82bbbae92
#   Fetching report 47 of 2160 for campaign ID: aad1129fd2
#   Fetching report 48 of 2160 for campaign ID: 9b1665ed6d
#   Fetching report 49 of 2160 for campaign ID: 2fa6b1893f
#   Fetching report 50 of 2160 for campaign ID: 411c3e9103
#   Fetching report 51 of 2160 for campaign ID: 87beb410b3
#   Fetching report 52 of 2160 for campaign ID: 9b0cf1a96f
#   Fetching report 53 of 2160 for campaign ID: 2282a9bcd2
#   Fetching report 54 of 2160 for campaign ID: d63de4225d
#   Fetching report 55 of 2160 for campaign ID: 0932825030
#   Fetching report 56 of 2160 for campaign ID: 0b1c5cd53d
#   Fetching report 57 of 2160 for campaign ID: b06e7dbfcd
#   Fetching report 58 of 2160 for campaign ID: 59dec38c99
#   Fetching report 59 of 2160 for campaign ID: 552f7e7125
#   Fetching report 60 of 2160 for campaign ID: 11ed63e56c
#   Fetching report 61 of 2160 for campaign ID: fcfb31a1ab
#   Fetching report 62 of 2160 for campaign ID: 70bb72b82b
#   Fetching report 63 of 2160 for campaign ID: 1c66f5a906
#   Fetching report 64 of 2160 for campaign ID: 38a8b46d0a
#   Fetching report 65 of 2160 for campaign ID: a1084b37eb
#   Fetching report 66 of 2160 for campaign ID: db8c2fc385
#   Fetching report 67 of 2160 for campaign ID: 3029164fc8
#   Fetching report 68 of 2160 for campaign ID: 7b867ac715
#   Fetching report 69 of 2160 for campaign ID: b79b4b44be
#   Fetching report 70 of 2160 for campaign ID: 77c8473169
#   Fetching report 71 of 2160 for campaign ID: 97996b869b
#   Fetching report 72 of 2160 for campaign ID: e919370d25
#   Fetching report 73 of 2160 for campaign ID: 2abf9ba44f
#   Fetching report 74 of 2160 for campaign ID: 5e23f3810f
#   Fetching report 75 of 2160 for campaign ID: 40b448c265
#   Fetching report 76 of 2160 for campaign ID: aa51740948
#   Fetching report 77 of 2160 for campaign ID: a6c8e5fc05
#   Fetching report 78 of 2160 for campaign ID: e3a9532ad8
#   Fetching report 79 of 2160 for campaign ID: 6063ade5c7
#   Fetching report 80 of 2160 for campaign ID: 688608ae7d
#   Fetching report 81 of 2160 for campaign ID: 91dc9f89fe
#   Fetching report 82 of 2160 for campaign ID: c874a1a238
#   Fetching report 83 of 2160 for campaign ID: 142ba0682a
#   Fetching report 84 of 2160 for campaign ID: bea566b590
#   Fetching report 85 of 2160 for campaign ID: 0269bb6539
#   Fetching report 86 of 2160 for campaign ID: f9153f46fb
#   Fetching report 87 of 2160 for campaign ID: 0af2319813
#   Fetching report 88 of 2160 for campaign ID: a007bfdc45
#   Fetching report 89 of 2160 for campaign ID: 2fb2c83abc
#   Fetching report 90 of 2160 for campaign ID: a054d911c4
#   Fetching report 91 of 2160 for campaign ID: 6579cd6b72
#   Fetching report 92 of 2160 for campaign ID: 81337d29ff
#   Fetching report 93 of 2160 for campaign ID: 3043e9e32d
#   Fetching report 94 of 2160 for campaign ID: 88d88b5f17
#   Fetching report 95 of 2160 for campaign ID: 4657605478
#   Fetching report 96 of 2160 for campaign ID: 6012c00430
#   Fetching report 97 of 2160 for campaign ID: a734a87d83
#   Fetching report 98 of 2160 for campaign ID: bbe7d298f7
#   Fetching report 99 of 2160 for campaign ID: 7ec24db490
#   Fetching report 100 of 2160 for campaign ID: 3980fd8079
#   Fetching report 101 of 2160 for campaign ID: 630f5a80f7
#   Fetching report 102 of 2160 for campaign ID: 24e876c3dd
#   Fetching report 103 of 2160 for campaign ID: 89dc9cbd19
#   Fetching report 104 of 2160 for campaign ID: 6d01f25f8b
#   Fetching report 105 of 2160 for campaign ID: b7081c0d38
#   Fetching report 106 of 2160 for campaign ID: 69e5acdaa1
#   Fetching report 107 of 2160 for campaign ID: ec014949a5
#   Fetching report 108 of 2160 for campaign ID: acb0ce56d6
#   Fetching report 109 of 2160 for campaign ID: cd76ec7a53
#   Fetching report 110 of 2160 for campaign ID: d28327e57e
#   Fetching report 111 of 2160 for campaign ID: 79aab11bb6
#   Fetching report 112 of 2160 for campaign ID: 153a4383d0
#   Fetching report 113 of 2160 for campaign ID: 7d76454431
#   Fetching report 114 of 2160 for campaign ID: 32246b6e41
#   Fetching report 115 of 2160 for campaign ID: 7a28a6d354
#   Fetching report 116 of 2160 for campaign ID: fdc70a4593
#   Fetching report 117 of 2160 for campaign ID: 4b95a625b1
#   Fetching report 118 of 2160 for campaign ID: 90e86a1ab5
#   Fetching report 119 of 2160 for campaign ID: 80ca4dfef5
#   Fetching report 120 of 2160 for campaign ID: da0c77fb93
#   Fetching report 121 of 2160 for campaign ID: 76f98a0568
#   Fetching report 122 of 2160 for campaign ID: cdcefc87b4
#   Fetching report 123 of 2160 for campaign ID: 1dfd467904
#   Fetching report 124 of 2160 for campaign ID: 462740d983
#   Fetching report 125 of 2160 for campaign ID: 12b7011a33
#   Fetching report 126 of 2160 for campaign ID: fc30a46f1a
#   Fetching report 127 of 2160 for campaign ID: 4c7cbc590a
#   Fetching report 128 of 2160 for campaign ID: 5fcd0876cb
#   Fetching report 129 of 2160 for campaign ID: 52889d1d54
#   Fetching report 130 of 2160 for campaign ID: cbdf51a318
#   Fetching report 131 of 2160 for campaign ID: ffc004389f
#   Fetching report 132 of 2160 for campaign ID: 30e13bb8ca
#   Fetching report 133 of 2160 for campaign ID: 85fecbff29
#   Fetching report 134 of 2160 for campaign ID: d641222dae
#   Fetching report 135 of 2160 for campaign ID: 3d840a5a0e
#   Fetching report 136 of 2160 for campaign ID: bef58f551e
#   Fetching report 137 of 2160 for campaign ID: 0fc5039244
#   Fetching report 138 of 2160 for campaign ID: 7eaaaa2b2e
#   Fetching report 139 of 2160 for campaign ID: 4ca78b2fab
#   Fetching report 140 of 2160 for campaign ID: 7734a878e9
#   Fetching report 141 of 2160 for campaign ID: 3e477d8f3d
#   Fetching report 142 of 2160 for campaign ID: 3cc0e7c95f
#   Fetching report 143 of 2160 for campaign ID: cf360224be
#   Fetching report 144 of 2160 for campaign ID: 0b647484bf
#   Fetching report 145 of 2160 for campaign ID: 5e5497dc95
#   Fetching report 146 of 2160 for campaign ID: c93cdd9ae9
#   Fetching report 147 of 2160 for campaign ID: 8501506269
#   Fetching report 148 of 2160 for campaign ID: 0bbdb64b27
#   Fetching report 149 of 2160 for campaign ID: 41f20fa291
#   Fetching report 150 of 2160 for campaign ID: 1f29b8aca3
#   Fetching report 151 of 2160 for campaign ID: 0d8948f4a7
#   Fetching report 152 of 2160 for campaign ID: 223bf237e9
#   Fetching report 153 of 2160 for campaign ID: 61aad66de3
#   Fetching report 154 of 2160 for campaign ID: 0d41d08c63
#   Fetching report 155 of 2160 for campaign ID: d8288e0c3e
#   Fetching report 156 of 2160 for campaign ID: ce84b45fe8
#   Fetching report 157 of 2160 for campaign ID: ce9db0fe32
#   Fetching report 158 of 2160 for campaign ID: 429894184d
#   Fetching report 159 of 2160 for campaign ID: cd149c1056
#   Fetching report 160 of 2160 for campaign ID: 578754b56d
#   Fetching report 161 of 2160 for campaign ID: c613bf927d
#   Fetching report 162 of 2160 for campaign ID: 340396470d
#   Fetching report 163 of 2160 for campaign ID: 1691bd60b3
#   Fetching report 164 of 2160 for campaign ID: f3dc3e2946
#   Fetching report 165 of 2160 for campaign ID: cd7d544f8f
#   Fetching report 166 of 2160 for campaign ID: 8d436b2198
#   Fetching report 167 of 2160 for campaign ID: 20e3642c96
#   Fetching report 168 of 2160 for campaign ID: 38f0147a80
#   Fetching report 169 of 2160 for campaign ID: f67fdee97c
#   Fetching report 170 of 2160 for campaign ID: 03ce83edf8
#   Fetching report 171 of 2160 for campaign ID: 78691ee7e9
#   Fetching report 172 of 2160 for campaign ID: 3a6b99de0f
#   Fetching report 173 of 2160 for campaign ID: 477d747756
#   Fetching report 174 of 2160 for campaign ID: 98095d0948
#   Fetching report 175 of 2160 for campaign ID: 87abcc03ec
#   Fetching report 176 of 2160 for campaign ID: e6c226f904
#   Fetching report 177 of 2160 for campaign ID: 40ee0883b5
#   Fetching report 178 of 2160 for campaign ID: f9271efa08
#   Fetching report 179 of 2160 for campaign ID: 5c1653b3b8
#   Fetching report 180 of 2160 for campaign ID: 62895c1a7a
#   Fetching report 181 of 2160 for campaign ID: 6df9a41ad9
#   Fetching report 182 of 2160 for campaign ID: 4b78f27b4e
#   Fetching report 183 of 2160 for campaign ID: 52364409cf
#   Fetching report 184 of 2160 for campaign ID: 91c381cfa5
#   Fetching report 185 of 2160 for campaign ID: 652908ed08
#   Fetching report 186 of 2160 for campaign ID: 1c95198b91
#   Fetching report 187 of 2160 for campaign ID: 31cfc49eff
#   Fetching report 188 of 2160 for campaign ID: 31027793bf
#   Fetching report 189 of 2160 for campaign ID: 2a44016c43
#   Fetching report 190 of 2160 for campaign ID: 51a5efed37
#   Fetching report 191 of 2160 for campaign ID: fd8c66e6e5
#   Fetching report 192 of 2160 for campaign ID: 0d15b92d34
#   Fetching report 193 of 2160 for campaign ID: 28c5789737
#   Fetching report 194 of 2160 for campaign ID: d565480972
#   Fetching report 195 of 2160 for campaign ID: 35bf35759e
#   Fetching report 196 of 2160 for campaign ID: 439b1d635b
#   Fetching report 197 of 2160 for campaign ID: e573d1778d
#   Fetching report 198 of 2160 for campaign ID: 357ce97436
#   Fetching report 199 of 2160 for campaign ID: 3da422790a
#   Fetching report 200 of 2160 for campaign ID: 1b5bd19bd4
#   Fetching report 201 of 2160 for campaign ID: dd9a8988f8
#   Fetching report 202 of 2160 for campaign ID: aabc24b041
#   Fetching report 203 of 2160 for campaign ID: 50e186d3e4
#   Fetching report 204 of 2160 for campaign ID: 6d80e191a8
#   Fetching report 205 of 2160 for campaign ID: bb9dbbcb07
#   Fetching report 206 of 2160 for campaign ID: fd438a99f8
#   Fetching report 207 of 2160 for campaign ID: c75e8938a3
#   Fetching report 208 of 2160 for campaign ID: 2c9eeb292a
#   Fetching report 209 of 2160 for campaign ID: dbcf5d19b2
#   Fetching report 210 of 2160 for campaign ID: 1fd3b44adc
#   Fetching report 211 of 2160 for campaign ID: 7209995aef
#   Fetching report 212 of 2160 for campaign ID: 5de655a8b9
#   Fetching report 213 of 2160 for campaign ID: 5539dfab15
#   Fetching report 214 of 2160 for campaign ID: 7bb39082e9
#   Fetching report 215 of 2160 for campaign ID: 3673c68e65
#   Fetching report 216 of 2160 for campaign ID: 75061beed3
#   Fetching report 217 of 2160 for campaign ID: 9b64410697
#   Fetching report 218 of 2160 for campaign ID: 5a9f46d0cb
#   Fetching report 219 of 2160 for campaign ID: fbda903109
#   Fetching report 220 of 2160 for campaign ID: 820dced800
#   Fetching report 221 of 2160 for campaign ID: aac8a5db1d
#   Fetching report 222 of 2160 for campaign ID: d34e77cb23
#   Fetching report 223 of 2160 for campaign ID: 8e7d2d7317
#   Fetching report 224 of 2160 for campaign ID: 8e7b78cc64
#   Fetching report 225 of 2160 for campaign ID: 7c5477e3f6
#   Fetching report 226 of 2160 for campaign ID: a44ce7f9cf
#   Fetching report 227 of 2160 for campaign ID: a5b403ad3d
#   Fetching report 228 of 2160 for campaign ID: 8242024db6
#   Fetching report 229 of 2160 for campaign ID: 44894d9db8
#   Fetching report 230 of 2160 for campaign ID: c2a080911a
#   Fetching report 231 of 2160 for campaign ID: 5a5e2779f8
#   Fetching report 232 of 2160 for campaign ID: 5dba6e7584
#   Fetching report 233 of 2160 for campaign ID: 163044143f
#   Fetching report 234 of 2160 for campaign ID: 316b7b71ab
#   Fetching report 235 of 2160 for campaign ID: b2028817f6
#   Fetching report 236 of 2160 for campaign ID: 441dae59bd
#   Fetching report 237 of 2160 for campaign ID: 78797818dd
#   Fetching report 238 of 2160 for campaign ID: a64e253362
#   Fetching report 239 of 2160 for campaign ID: c5cf2a08f5
#   Fetching report 240 of 2160 for campaign ID: 93be0dc23f
#   Fetching report 241 of 2160 for campaign ID: 4ee32f72f1
#   Fetching report 242 of 2160 for campaign ID: a0ab19c2ef
#   Fetching report 243 of 2160 for campaign ID: a1b0bb7499
#   Fetching report 244 of 2160 for campaign ID: f543d02308
#   Fetching report 245 of 2160 for campaign ID: 9aea53f73f
#   Fetching report 246 of 2160 for campaign ID: e5e989a196
#   Fetching report 247 of 2160 for campaign ID: 4f845dd49e
#   Fetching report 248 of 2160 for campaign ID: 416a34f170
#   Fetching report 249 of 2160 for campaign ID: 8b2d0d5096
#   Fetching report 250 of 2160 for campaign ID: e10487848f
#   Fetching report 251 of 2160 for campaign ID: 6e12f3e53b
#   Fetching report 252 of 2160 for campaign ID: 78f90f1cd7
#   Fetching report 253 of 2160 for campaign ID: 1a34dbca09
#   Fetching report 254 of 2160 for campaign ID: 7a89cea313
#   Fetching report 255 of 2160 for campaign ID: 63bbdb1845
#   Fetching report 256 of 2160 for campaign ID: 7020d0b578
#   Fetching report 257 of 2160 for campaign ID: 12d4bf8349
#   Fetching report 258 of 2160 for campaign ID: b9cbf44811
#   Fetching report 259 of 2160 for campaign ID: d93c73f035
#   Fetching report 260 of 2160 for campaign ID: 544b98b0eb
#   Fetching report 261 of 2160 for campaign ID: e418a41b4f
#   Fetching report 262 of 2160 for campaign ID: ba4c9d63a4
#   Fetching report 263 of 2160 for campaign ID: 0ab3125d8e
#   Fetching report 264 of 2160 for campaign ID: f923375416
#   Fetching report 265 of 2160 for campaign ID: 830a876bdf
#   Fetching report 266 of 2160 for campaign ID: b9a79dc506
#   Fetching report 267 of 2160 for campaign ID: 3d4059ee9b
#   Fetching report 268 of 2160 for campaign ID: fcf593f793
#   Fetching report 269 of 2160 for campaign ID: 31d1e099b3
#   Fetching report 270 of 2160 for campaign ID: b1809181cb
#   Fetching report 271 of 2160 for campaign ID: 6a5fb5254c
#   Fetching report 272 of 2160 for campaign ID: 3af7b3df8a
#   Fetching report 273 of 2160 for campaign ID: c417633942
#   Fetching report 274 of 2160 for campaign ID: 7d4515522f
#   Fetching report 275 of 2160 for campaign ID: 7ccfe8425e
#   Fetching report 276 of 2160 for campaign ID: adc81196ae
#   Fetching report 277 of 2160 for campaign ID: c222c37416
#   Fetching report 278 of 2160 for campaign ID: e6fbd187e6
#   Fetching report 279 of 2160 for campaign ID: f4ef71ff48
#   Fetching report 280 of 2160 for campaign ID: 70b44c9196
#   Fetching report 281 of 2160 for campaign ID: 84044ad38e
#   Fetching report 282 of 2160 for campaign ID: d23cb33245
#   Fetching report 283 of 2160 for campaign ID: 9d854e5bcb
#   Fetching report 284 of 2160 for campaign ID: 84e600ea15
#   Fetching report 285 of 2160 for campaign ID: d911e30a5e
#   Fetching report 286 of 2160 for campaign ID: 6dea42c837
#   Fetching report 287 of 2160 for campaign ID: fa5ffe814a
#   Fetching report 288 of 2160 for campaign ID: 7b5e8ffff5
#   Fetching report 289 of 2160 for campaign ID: a1420c0609
#   Fetching report 290 of 2160 for campaign ID: 1f2d612612
#   Fetching report 291 of 2160 for campaign ID: fec25071bf
#   Fetching report 292 of 2160 for campaign ID: da5bae523e
#   Fetching report 293 of 2160 for campaign ID: 138fbbbe78
#   Fetching report 294 of 2160 for campaign ID: 2b4e686edf
#   Fetching report 295 of 2160 for campaign ID: 503e0f0b6f
#   Fetching report 296 of 2160 for campaign ID: cc3ecd7d84
#   Fetching report 297 of 2160 for campaign ID: d0beb21b9f
#   Fetching report 298 of 2160 for campaign ID: 434a882456
#   Fetching report 299 of 2160 for campaign ID: ef33f1a98b
#   Fetching report 300 of 2160 for campaign ID: 022d1c3daa
#   Fetching report 301 of 2160 for campaign ID: 8922549e14
#   Fetching report 302 of 2160 for campaign ID: 94ef06b245
#   Fetching report 303 of 2160 for campaign ID: dc85bef559
#   Fetching report 304 of 2160 for campaign ID: cb8b18a55a
#   Fetching report 305 of 2160 for campaign ID: e74d3e0fcb
#   Fetching report 306 of 2160 for campaign ID: 48fd91685b
#   Fetching report 307 of 2160 for campaign ID: f103385a2b
#   Fetching report 308 of 2160 for campaign ID: 6d3e681202
#   Fetching report 309 of 2160 for campaign ID: c28d150ec5
#   Fetching report 310 of 2160 for campaign ID: a77f61591e
#   Fetching report 311 of 2160 for campaign ID: 6867b49149
#   Fetching report 312 of 2160 for campaign ID: d39c6ad812
#   Fetching report 313 of 2160 for campaign ID: 0b002c38a4
#   Fetching report 314 of 2160 for campaign ID: b6b3fc4900
#   Fetching report 315 of 2160 for campaign ID: 7f62425210
#   Fetching report 316 of 2160 for campaign ID: 560aaae5ed
#   Fetching report 317 of 2160 for campaign ID: 758b80a1bd
#   Fetching report 318 of 2160 for campaign ID: db4ad105f9
#   Fetching report 319 of 2160 for campaign ID: d78b698bfb
#   Fetching report 320 of 2160 for campaign ID: 52d5e88590
#   Fetching report 321 of 2160 for campaign ID: e9320a97d6
#   Fetching report 322 of 2160 for campaign ID: 1d470e3102
#   Fetching report 323 of 2160 for campaign ID: 12dfbac71d
#   Fetching report 324 of 2160 for campaign ID: d2fe6863a1
#   Fetching report 325 of 2160 for campaign ID: 7e6c1b1b13
#   Fetching report 326 of 2160 for campaign ID: 4f8ee30cb9
#   Fetching report 327 of 2160 for campaign ID: 161e665144
#   Fetching report 328 of 2160 for campaign ID: 91d820d41f
#   Fetching report 329 of 2160 for campaign ID: 31d09658d3
#   Fetching report 330 of 2160 for campaign ID: 457ef29149
#   Fetching report 331 of 2160 for campaign ID: fea12c9642
#   Fetching report 332 of 2160 for campaign ID: be226dee81
#   Fetching report 333 of 2160 for campaign ID: 236a7d8962
#   Fetching report 334 of 2160 for campaign ID: e93916bad8
#   Fetching report 335 of 2160 for campaign ID: 07c8feea5b
#   Fetching report 336 of 2160 for campaign ID: bdac8ad946
#   Fetching report 337 of 2160 for campaign ID: a1a4f0113f
#   Fetching report 338 of 2160 for campaign ID: 9d686b8798
#   Fetching report 339 of 2160 for campaign ID: 56a29f348a
#   Fetching report 340 of 2160 for campaign ID: 221d27694b
#   Fetching report 341 of 2160 for campaign ID: 9b9daaee7f
#   Fetching report 342 of 2160 for campaign ID: fdc7a7b72a
#   Fetching report 343 of 2160 for campaign ID: 80cbb42228
#   Fetching report 344 of 2160 for campaign ID: f158ebafc2
#   Fetching report 345 of 2160 for campaign ID: 968a6d0f70
#   Fetching report 346 of 2160 for campaign ID: f2e8774fad
#   Fetching report 347 of 2160 for campaign ID: fabf04220c
#   Fetching report 348 of 2160 for campaign ID: 35ff3de4ce
#   Fetching report 349 of 2160 for campaign ID: 60e74ac977
#   Fetching report 350 of 2160 for campaign ID: 021a45d3df
#   Fetching report 351 of 2160 for campaign ID: 7f5bcf7fe4
#   Fetching report 352 of 2160 for campaign ID: 47a6cf5f9a
#   Fetching report 353 of 2160 for campaign ID: 355185c464
#   Fetching report 354 of 2160 for campaign ID: a5a2cad7f9
#   Fetching report 355 of 2160 for campaign ID: 06ebac9a5e
#   Fetching report 356 of 2160 for campaign ID: 4874bd069f
#   Fetching report 357 of 2160 for campaign ID: 4bd6c83b24
#   Fetching report 358 of 2160 for campaign ID: 6fd1a0a529
#   Fetching report 359 of 2160 for campaign ID: 47b9905d07
#   Fetching report 360 of 2160 for campaign ID: 14c99685c4
#   Fetching report 361 of 2160 for campaign ID: 13fe9b84a4
#   Fetching report 362 of 2160 for campaign ID: 27190c7e73
#   Fetching report 363 of 2160 for campaign ID: 925395c56e
#   Fetching report 364 of 2160 for campaign ID: 545fbe91d8
#   Fetching report 365 of 2160 for campaign ID: 3d234915a4
#   Fetching report 366 of 2160 for campaign ID: 5be3260bde
#   Fetching report 367 of 2160 for campaign ID: a9a4de057a
#   Fetching report 368 of 2160 for campaign ID: 613e0b2f42
#   Fetching report 369 of 2160 for campaign ID: 82670b56f9
#   Fetching report 370 of 2160 for campaign ID: ae6e147fd7
#   Fetching report 371 of 2160 for campaign ID: 4605946c27
#   Fetching report 372 of 2160 for campaign ID: 2779480026
#   Fetching report 373 of 2160 for campaign ID: 6f4ff1401f
#   Fetching report 374 of 2160 for campaign ID: 4a7d038789
#   Fetching report 375 of 2160 for campaign ID: 58b867aea4
#   Fetching report 376 of 2160 for campaign ID: 52c44e7093
#   Fetching report 377 of 2160 for campaign ID: a5de5c8fa9
#   Fetching report 378 of 2160 for campaign ID: 21b517b3be
#   Fetching report 379 of 2160 for campaign ID: 46083982a5
#   Fetching report 380 of 2160 for campaign ID: e339e06eb3
#   Fetching report 381 of 2160 for campaign ID: 5393fcd0af
#   Fetching report 382 of 2160 for campaign ID: ca28d7f858
#   Fetching report 383 of 2160 for campaign ID: d29db806d5
#   Fetching report 384 of 2160 for campaign ID: c1d86c64c7
#   Fetching report 385 of 2160 for campaign ID: 6b3ef7d86a
#   Fetching report 386 of 2160 for campaign ID: 2a8bd45c23
#   Fetching report 387 of 2160 for campaign ID: 337d009c8c
#   Fetching report 388 of 2160 for campaign ID: 01654609e0
#   Fetching report 389 of 2160 for campaign ID: f379d95c79
#   Fetching report 390 of 2160 for campaign ID: d682f06e65
#   Fetching report 391 of 2160 for campaign ID: 9f5d3f5c4d
#   Fetching report 392 of 2160 for campaign ID: ccc1375950
#   Fetching report 393 of 2160 for campaign ID: c99f312d26
#   Fetching report 394 of 2160 for campaign ID: 92f85067f7
#   Fetching report 395 of 2160 for campaign ID: f4eba67e57
#   Fetching report 396 of 2160 for campaign ID: 429317193e
#   Fetching report 397 of 2160 for campaign ID: f5411e3d2c
#   Fetching report 398 of 2160 for campaign ID: 0fba1961cf
#   Fetching report 399 of 2160 for campaign ID: cac021fe66
#   Fetching report 400 of 2160 for campaign ID: 02baba14e4
#   Fetching report 401 of 2160 for campaign ID: f1b3aab31e
#   Fetching report 402 of 2160 for campaign ID: 02e4f0ef45
#   Fetching report 403 of 2160 for campaign ID: 6cb570c379
#   Fetching report 404 of 2160 for campaign ID: adc8510cf0
#   Fetching report 405 of 2160 for campaign ID: c3045693c7
#   Fetching report 406 of 2160 for campaign ID: 1628aed806
#   Fetching report 407 of 2160 for campaign ID: e18bcfdbb9
#   Fetching report 408 of 2160 for campaign ID: 917634cdc1
#   Fetching report 409 of 2160 for campaign ID: a85c0b3fdf
#   Fetching report 410 of 2160 for campaign ID: 403499e09f
#   Fetching report 411 of 2160 for campaign ID: 272ce9c137
#   Fetching report 412 of 2160 for campaign ID: f865998d7a
#   Fetching report 413 of 2160 for campaign ID: df00c4ea6a
#   Fetching report 414 of 2160 for campaign ID: e41c9bed3f
#   Fetching report 415 of 2160 for campaign ID: a87a3e8959
#   Fetching report 416 of 2160 for campaign ID: 14d52eb039
#   Fetching report 417 of 2160 for campaign ID: 98ad732ad0
#   Fetching report 418 of 2160 for campaign ID: 337b17bf95
#   Fetching report 419 of 2160 for campaign ID: db4a997329
#   Fetching report 420 of 2160 for campaign ID: e8d0b09040
#   Fetching report 421 of 2160 for campaign ID: e6723c9c4a
#   Fetching report 422 of 2160 for campaign ID: 765a56d395
#   Fetching report 423 of 2160 for campaign ID: da2e3f3d53
#   Fetching report 424 of 2160 for campaign ID: 3848e8c3ee
#   Fetching report 425 of 2160 for campaign ID: c1f65ae74a
#   Fetching report 426 of 2160 for campaign ID: ca69481d0d
#   Fetching report 427 of 2160 for campaign ID: 7131825997
#   Fetching report 428 of 2160 for campaign ID: 7a004cb5d1
#   Fetching report 429 of 2160 for campaign ID: 81d5a7040f
#   Fetching report 430 of 2160 for campaign ID: 6d1b36acca
#   Fetching report 431 of 2160 for campaign ID: faa9f77c65
#   Fetching report 432 of 2160 for campaign ID: 719cc1d8b9
#   Fetching report 433 of 2160 for campaign ID: ce40394151
#   Fetching report 434 of 2160 for campaign ID: 70aece893f
#   Fetching report 435 of 2160 for campaign ID: 6cfbed3fcd
#   Fetching report 436 of 2160 for campaign ID: 6ca670f588
#   Fetching report 437 of 2160 for campaign ID: ff3a0f65b6
#   Fetching report 438 of 2160 for campaign ID: 171f8ac140
#   Fetching report 439 of 2160 for campaign ID: a769376fed
#   Fetching report 440 of 2160 for campaign ID: 1095318b6a
#   Fetching report 441 of 2160 for campaign ID: add2e792b6
#   Fetching report 442 of 2160 for campaign ID: 4085b020d9
#   Fetching report 443 of 2160 for campaign ID: 160de5b4cd
#   Fetching report 444 of 2160 for campaign ID: 663658ec97
#   Fetching report 445 of 2160 for campaign ID: 5dc70b8e46
#   Fetching report 446 of 2160 for campaign ID: b52d83bab4
#   Fetching report 447 of 2160 for campaign ID: 28a0f304b4
#   Fetching report 448 of 2160 for campaign ID: 3adcac6ff7
#   Fetching report 449 of 2160 for campaign ID: 5e2323b3a3
#   Fetching report 450 of 2160 for campaign ID: b5520e2f42
#   Fetching report 451 of 2160 for campaign ID: d3e14861e8
#   Fetching report 452 of 2160 for campaign ID: 4056a57b9f
#   Fetching report 453 of 2160 for campaign ID: 8521c097f7
#   Fetching report 454 of 2160 for campaign ID: 15e83e1cc1
#   Fetching report 455 of 2160 for campaign ID: 6bb47628d8
#   Fetching report 456 of 2160 for campaign ID: 6ecb681e14
#   Fetching report 457 of 2160 for campaign ID: 7d2f647fbf
#   Fetching report 458 of 2160 for campaign ID: 0bee98c969
#   Fetching report 459 of 2160 for campaign ID: 4755ca9466
#   Fetching report 460 of 2160 for campaign ID: 7d1709c798
#   Fetching report 461 of 2160 for campaign ID: 838038d310
#   Fetching report 462 of 2160 for campaign ID: 79b60e2b73
#   Fetching report 463 of 2160 for campaign ID: d23ebf43ae
#   Fetching report 464 of 2160 for campaign ID: a37734d3dc
#   Fetching report 465 of 2160 for campaign ID: 806faa0399
#   Fetching report 466 of 2160 for campaign ID: ed4fba9d8c
#   Fetching report 467 of 2160 for campaign ID: 66d8be5701
#   Fetching report 468 of 2160 for campaign ID: 83e3b71fea
#   Fetching report 469 of 2160 for campaign ID: dbd36ca8ba
#   Fetching report 470 of 2160 for campaign ID: aed1b253d8
#   Fetching report 471 of 2160 for campaign ID: d56b726f9b
#   Fetching report 472 of 2160 for campaign ID: 7f0760fe4e
#   Fetching report 473 of 2160 for campaign ID: 2e3bb31e0f
#   Fetching report 474 of 2160 for campaign ID: e2de85abf0
#   Fetching report 475 of 2160 for campaign ID: 8c779914f6
#   Fetching report 476 of 2160 for campaign ID: 4eda61978e
#   Fetching report 477 of 2160 for campaign ID: 7de54adf36
#   Fetching report 478 of 2160 for campaign ID: e4bc62f7cb
#   Fetching report 479 of 2160 for campaign ID: b5e6104402
#   Fetching report 480 of 2160 for campaign ID: f26c3930e5
#   Fetching report 481 of 2160 for campaign ID: 895993fa56
#   Fetching report 482 of 2160 for campaign ID: a3055c278f
#   Fetching report 483 of 2160 for campaign ID: d5a35744cf
#   Fetching report 484 of 2160 for campaign ID: b965fb5171
#   Fetching report 485 of 2160 for campaign ID: df19b1e614
#   Fetching report 486 of 2160 for campaign ID: 8ed9617f56
#   Fetching report 487 of 2160 for campaign ID: a46e696cfb
#   Fetching report 488 of 2160 for campaign ID: ba831cc3ae
#   Fetching report 489 of 2160 for campaign ID: 70e77b6e81
#   Fetching report 490 of 2160 for campaign ID: 1535a2a1a8
#   Fetching report 491 of 2160 for campaign ID: dc9a9fd00b
#   Fetching report 492 of 2160 for campaign ID: 631b367841
#   Fetching report 493 of 2160 for campaign ID: 9c788b8233
#   Fetching report 494 of 2160 for campaign ID: 5456991e63
#   Fetching report 495 of 2160 for campaign ID: 72b30ceb3f
#   Fetching report 496 of 2160 for campaign ID: 9640c099f6
#   Fetching report 497 of 2160 for campaign ID: a50ac6497f
#   Fetching report 498 of 2160 for campaign ID: 5ba28889db
#   Fetching report 499 of 2160 for campaign ID: c26621790e
#   Fetching report 500 of 2160 for campaign ID: 7ba180c989
#   Fetching report 501 of 2160 for campaign ID: be0d61b0e3
#   Fetching report 502 of 2160 for campaign ID: 145946b015
#   Fetching report 503 of 2160 for campaign ID: f4725a7117
#   Fetching report 504 of 2160 for campaign ID: 79526a4121
#   Fetching report 505 of 2160 for campaign ID: 6040a81116
#   Fetching report 506 of 2160 for campaign ID: 09a27cfc30
#   Fetching report 507 of 2160 for campaign ID: e2314d8687
#   Fetching report 508 of 2160 for campaign ID: cba2a95212
#   Fetching report 509 of 2160 for campaign ID: d4cec40351
#   Fetching report 510 of 2160 for campaign ID: d4931b7c7e
#   Fetching report 511 of 2160 for campaign ID: bb5d552d7f
#   Fetching report 512 of 2160 for campaign ID: be632be517
#   Fetching report 513 of 2160 for campaign ID: b3de2ebc7e
#   Fetching report 514 of 2160 for campaign ID: 550728657d
#   Fetching report 515 of 2160 for campaign ID: fa7c318de3
#   Fetching report 516 of 2160 for campaign ID: fcf3f57bb3
#   Fetching report 517 of 2160 for campaign ID: 76a85b8527
#   Fetching report 518 of 2160 for campaign ID: a59b74c7af
#   Fetching report 519 of 2160 for campaign ID: 78e8197449
#   Fetching report 520 of 2160 for campaign ID: 52cb9bfc6d
#   Fetching report 521 of 2160 for campaign ID: e4d4aba9a3
#   Fetching report 522 of 2160 for campaign ID: 67f8baceac
#   Fetching report 523 of 2160 for campaign ID: 6f20ef8fbb
#   Fetching report 524 of 2160 for campaign ID: fefe4d2bf2
#   Fetching report 525 of 2160 for campaign ID: 570ee0383c
#   Fetching report 526 of 2160 for campaign ID: bcac1934d6
#   Fetching report 527 of 2160 for campaign ID: 315051375c
#   Fetching report 528 of 2160 for campaign ID: 26ef244290
#   Fetching report 529 of 2160 for campaign ID: 2da67d0711
#   Fetching report 530 of 2160 for campaign ID: 312891e36c
#   Fetching report 531 of 2160 for campaign ID: 3a60c64c46
#   Fetching report 532 of 2160 for campaign ID: 472e386a03
#   Fetching report 533 of 2160 for campaign ID: a562f2092e
#   Fetching report 534 of 2160 for campaign ID: dee7c95283
#   Fetching report 535 of 2160 for campaign ID: c4407d75fc
#   Fetching report 536 of 2160 for campaign ID: 2ad9b693de
#   Fetching report 537 of 2160 for campaign ID: bcb4664f81
#   Fetching report 538 of 2160 for campaign ID: b0578ee896
#   Fetching report 539 of 2160 for campaign ID: 5ad4bc5483
#   Fetching report 540 of 2160 for campaign ID: ab589b7743
#   Fetching report 541 of 2160 for campaign ID: 37c8385f2f
#   Fetching report 542 of 2160 for campaign ID: 781893328d
#   Fetching report 543 of 2160 for campaign ID: 60747e0384
#   Fetching report 544 of 2160 for campaign ID: e5dcae6d0b
#   Fetching report 545 of 2160 for campaign ID: b09a543b85
#   Fetching report 546 of 2160 for campaign ID: def517a2c8
#   Fetching report 547 of 2160 for campaign ID: 87342a4106
#   Fetching report 548 of 2160 for campaign ID: ccc3acb5c4
#   Fetching report 549 of 2160 for campaign ID: 81e037c268
#   Fetching report 550 of 2160 for campaign ID: 2d207f8193
#   Fetching report 551 of 2160 for campaign ID: 00910e836f
#   Fetching report 552 of 2160 for campaign ID: 4f968058a9
#   Fetching report 553 of 2160 for campaign ID: 17283f9523
#   Fetching report 554 of 2160 for campaign ID: 5a6d6cf614
#   Fetching report 555 of 2160 for campaign ID: 8bfed23a8c
#   Fetching report 556 of 2160 for campaign ID: 53b796a772
#   Fetching report 557 of 2160 for campaign ID: 5665f83182
#   Fetching report 558 of 2160 for campaign ID: 05257aa658
#   Fetching report 559 of 2160 for campaign ID: 822628b10e
#   Fetching report 560 of 2160 for campaign ID: 4be77314de
#   Fetching report 561 of 2160 for campaign ID: 1a2abe6790
#   Fetching report 562 of 2160 for campaign ID: 520b0473f1
#   Fetching report 563 of 2160 for campaign ID: ac51feb9ef
#   Fetching report 564 of 2160 for campaign ID: 18becf335e
#   Fetching report 565 of 2160 for campaign ID: 570ca083fc
#   Fetching report 566 of 2160 for campaign ID: a08d99035d
#   Fetching report 567 of 2160 for campaign ID: 053c71e993
#   Fetching report 568 of 2160 for campaign ID: 42f80b5c98
#   Fetching report 569 of 2160 for campaign ID: 6a0192f0ee
#   Fetching report 570 of 2160 for campaign ID: 01deb487f5
#   Fetching report 571 of 2160 for campaign ID: 7148941549
#   Fetching report 572 of 2160 for campaign ID: f0553bb322
#   Fetching report 573 of 2160 for campaign ID: c068ef5fbd
#   Fetching report 574 of 2160 for campaign ID: 5cf6ebbe1e
#   Fetching report 575 of 2160 for campaign ID: 351c322bb9
#   Fetching report 576 of 2160 for campaign ID: 1eea89d38f
#   Fetching report 577 of 2160 for campaign ID: 6d066474e1
#   Fetching report 578 of 2160 for campaign ID: 5c68ecc6d1
#   Fetching report 579 of 2160 for campaign ID: f9a1281ca3
#   Fetching report 580 of 2160 for campaign ID: 32310aed0d
#   Fetching report 581 of 2160 for campaign ID: f16355bed3
#   Fetching report 582 of 2160 for campaign ID: 886c4abaf2
#   Fetching report 583 of 2160 for campaign ID: c36b389f83
#   Fetching report 584 of 2160 for campaign ID: fd532f6350
#   Fetching report 585 of 2160 for campaign ID: 377ab40572
#   Fetching report 586 of 2160 for campaign ID: 2b504106b0
#   Fetching report 587 of 2160 for campaign ID: 2d3f1eccd3
#   Fetching report 588 of 2160 for campaign ID: a09a5e062a
#   Fetching report 589 of 2160 for campaign ID: a85f44e8ad
#   Fetching report 590 of 2160 for campaign ID: 4e60ec6226
#   Fetching report 591 of 2160 for campaign ID: 6c1a225161
#   Fetching report 592 of 2160 for campaign ID: ae72debcbf
#   Fetching report 593 of 2160 for campaign ID: 30c4ecc944
#   Fetching report 594 of 2160 for campaign ID: e51f6bf954
#   Fetching report 595 of 2160 for campaign ID: 517c5c2638
#   Fetching report 596 of 2160 for campaign ID: 95d31e238b
#   Fetching report 597 of 2160 for campaign ID: aa7bce1a83
#   Fetching report 598 of 2160 for campaign ID: 3769fecab0
#   Fetching report 599 of 2160 for campaign ID: 30071261c9
#   Fetching report 600 of 2160 for campaign ID: 465341eab1
#   Fetching report 601 of 2160 for campaign ID: c95b409c12
#   Fetching report 602 of 2160 for campaign ID: 92a0d041ce
#   Fetching report 603 of 2160 for campaign ID: 7cc697dbb7
#   Fetching report 604 of 2160 for campaign ID: aa7cf7b383
#   Fetching report 605 of 2160 for campaign ID: a6f7c670d9
#   Fetching report 606 of 2160 for campaign ID: 6eae52519a
#   Fetching report 607 of 2160 for campaign ID: 8c75f9d4ae
#   Fetching report 608 of 2160 for campaign ID: 3c018e5a23
#   Fetching report 609 of 2160 for campaign ID: b7affa5db4
#   Fetching report 610 of 2160 for campaign ID: 38ad5e4f27
#   Fetching report 611 of 2160 for campaign ID: d5a423aa99
#   Fetching report 612 of 2160 for campaign ID: c118793f90
#   Fetching report 613 of 2160 for campaign ID: 5e22959567
#   Fetching report 614 of 2160 for campaign ID: a30674ca6d
#   Fetching report 615 of 2160 for campaign ID: d103714dac
#   Fetching report 616 of 2160 for campaign ID: 3d08a9f14f
#   Fetching report 617 of 2160 for campaign ID: 78b06ce0a9
#   Fetching report 618 of 2160 for campaign ID: 3cbbbbb9e8
#   Fetching report 619 of 2160 for campaign ID: 3294043059
#   Fetching report 620 of 2160 for campaign ID: 01962f41a0
#   Fetching report 621 of 2160 for campaign ID: 518ebaec28
#   Fetching report 622 of 2160 for campaign ID: 9dea5dc5b8
#   Fetching report 623 of 2160 for campaign ID: 2a64a635ee
#   Fetching report 624 of 2160 for campaign ID: 87d90acc3d
#   Fetching report 625 of 2160 for campaign ID: c4866bbe41
#   Fetching report 626 of 2160 for campaign ID: 1d2a530315
#   Fetching report 627 of 2160 for campaign ID: 974d70a804
#   Fetching report 628 of 2160 for campaign ID: b250d76134
#   Fetching report 629 of 2160 for campaign ID: df5e06b8e3
#   Fetching report 630 of 2160 for campaign ID: af6d357e04
#   Fetching report 631 of 2160 for campaign ID: bc35d5096a
#   Fetching report 632 of 2160 for campaign ID: cfbd783a9e
#   Fetching report 633 of 2160 for campaign ID: dc868d7cd0
#   Fetching report 634 of 2160 for campaign ID: 416db33544
#   Fetching report 635 of 2160 for campaign ID: 9c39f25473
#   Fetching report 636 of 2160 for campaign ID: 63b200643b
#   Fetching report 637 of 2160 for campaign ID: d400b908a4
#   Fetching report 638 of 2160 for campaign ID: fe8836267a
#   Fetching report 639 of 2160 for campaign ID: 873528eab9
#   Fetching report 640 of 2160 for campaign ID: 414f524178
#   Fetching report 641 of 2160 for campaign ID: ee32f1b420
#   Fetching report 642 of 2160 for campaign ID: e7665f0305
#   Fetching report 643 of 2160 for campaign ID: 111f646f5d
#   Fetching report 644 of 2160 for campaign ID: 04fc7789ee
#   Fetching report 645 of 2160 for campaign ID: cbb93a29af
#   Fetching report 646 of 2160 for campaign ID: 3af10fcaf2
#   Fetching report 647 of 2160 for campaign ID: 49a2b025bb
#   Fetching report 648 of 2160 for campaign ID: 487c67d748
#   Fetching report 649 of 2160 for campaign ID: c4baa534d6
#   Fetching report 650 of 2160 for campaign ID: e7b5577e66
#   Fetching report 651 of 2160 for campaign ID: af0311798a
#   Fetching report 652 of 2160 for campaign ID: d0b53cef6a
#   Fetching report 653 of 2160 for campaign ID: 532836cf71
#   Fetching report 654 of 2160 for campaign ID: ac3bd0c58b
#   Fetching report 655 of 2160 for campaign ID: 8a73a35371
#   Fetching report 656 of 2160 for campaign ID: 320119e6a5
#   Fetching report 657 of 2160 for campaign ID: f77c17d1a4
#   Fetching report 658 of 2160 for campaign ID: e79fcdae4d
#   Fetching report 659 of 2160 for campaign ID: bd849e10f8
#   Fetching report 660 of 2160 for campaign ID: 2f430bbf73
#   Fetching report 661 of 2160 for campaign ID: 7604cc7f9b
#   Fetching report 662 of 2160 for campaign ID: 5f300bae21
#   Fetching report 663 of 2160 for campaign ID: ac68be17c0
#   Fetching report 664 of 2160 for campaign ID: ec01462181
#   Fetching report 665 of 2160 for campaign ID: 7b59f8e85f
#   Fetching report 666 of 2160 for campaign ID: eecc977809
#   Fetching report 667 of 2160 for campaign ID: 3686f9d2e1
#   Fetching report 668 of 2160 for campaign ID: 541df62263
#   Fetching report 669 of 2160 for campaign ID: 46130df842
#   Fetching report 670 of 2160 for campaign ID: 9844dfc68c
#   Fetching report 671 of 2160 for campaign ID: f033f75aac
#   Fetching report 672 of 2160 for campaign ID: f21117c9b6
#   Fetching report 673 of 2160 for campaign ID: fa93767dc8
#   Fetching report 674 of 2160 for campaign ID: 902568b44f
#   Fetching report 675 of 2160 for campaign ID: d4cbe714e4
#   Fetching report 676 of 2160 for campaign ID: f3ac938b99
#   Fetching report 677 of 2160 for campaign ID: d410b9d0ed
#   Fetching report 678 of 2160 for campaign ID: 708b0c62b2
#   Fetching report 679 of 2160 for campaign ID: 68cebc7cb8
#   Fetching report 680 of 2160 for campaign ID: 1804c8df9f
#   Fetching report 681 of 2160 for campaign ID: 94f1f3228a
#   Fetching report 682 of 2160 for campaign ID: 27c080bedd
#   Fetching report 683 of 2160 for campaign ID: 2327cad15b
#   Fetching report 684 of 2160 for campaign ID: a6a985d9e1
#   Fetching report 685 of 2160 for campaign ID: c5ef900e91
#   Fetching report 686 of 2160 for campaign ID: 83ee71e9b7
#   Fetching report 687 of 2160 for campaign ID: 2a463cb3b7
#   Fetching report 688 of 2160 for campaign ID: 757f97f485
#   Fetching report 689 of 2160 for campaign ID: dc6d221b7e
#   Fetching report 690 of 2160 for campaign ID: 7e2f368592
#   Fetching report 691 of 2160 for campaign ID: bb60de1818
#   Fetching report 692 of 2160 for campaign ID: b43c41a93c
#   Fetching report 693 of 2160 for campaign ID: 97556f6df9
#   Fetching report 694 of 2160 for campaign ID: ede47bc4d3
#   Fetching report 695 of 2160 for campaign ID: e31773cfc7
#   Fetching report 696 of 2160 for campaign ID: e446998ef9
#   Fetching report 697 of 2160 for campaign ID: 056f8253e1
#   Fetching report 698 of 2160 for campaign ID: 9827400d29
#   Fetching report 699 of 2160 for campaign ID: 9961448777
#   Fetching report 700 of 2160 for campaign ID: ba9a9a5ca4
#   Fetching report 701 of 2160 for campaign ID: c045b3dca5
#   Fetching report 702 of 2160 for campaign ID: e8b2b7b15e
#   Fetching report 703 of 2160 for campaign ID: d62dd87f4a
#   Fetching report 704 of 2160 for campaign ID: d2e0a673c9
#   Fetching report 705 of 2160 for campaign ID: 81ba1825e4
#   Fetching report 706 of 2160 for campaign ID: 5ee8751b60
#   Fetching report 707 of 2160 for campaign ID: 8ffd57c24a
#   Fetching report 708 of 2160 for campaign ID: 9fcab883c4
#   Fetching report 709 of 2160 for campaign ID: a6dacd62d5
#   Fetching report 710 of 2160 for campaign ID: e1315e8158
#   Fetching report 711 of 2160 for campaign ID: 7f8c334ad9
#   Fetching report 712 of 2160 for campaign ID: 27454b35a0
#   Fetching report 713 of 2160 for campaign ID: 2ad63d555f
#   Fetching report 714 of 2160 for campaign ID: 485340b66c
#   Fetching report 715 of 2160 for campaign ID: eab926ddb4
#   Fetching report 716 of 2160 for campaign ID: 75b5f2e65d
#   Fetching report 717 of 2160 for campaign ID: c3341ded23
#   Fetching report 718 of 2160 for campaign ID: 4fdbfacd60
#   Fetching report 719 of 2160 for campaign ID: 8a9a983e00
#   Fetching report 720 of 2160 for campaign ID: 89a95e301d
#   Fetching report 721 of 2160 for campaign ID: 77a47ad5f0
#   Fetching report 722 of 2160 for campaign ID: 9895ca7794
#   Fetching report 723 of 2160 for campaign ID: eb15e198b5
#   Fetching report 724 of 2160 for campaign ID: 868da85ab3
#   Fetching report 725 of 2160 for campaign ID: 027a317d70
#   Fetching report 726 of 2160 for campaign ID: f63f29ad5d
#   Fetching report 727 of 2160 for campaign ID: 7718fab683
#   Fetching report 728 of 2160 for campaign ID: 59c311bc68
#   Fetching report 729 of 2160 for campaign ID: 22523526e1
#   Fetching report 730 of 2160 for campaign ID: 1ca133f6ed
#   Fetching report 731 of 2160 for campaign ID: 040dd7deb9
#   Fetching report 732 of 2160 for campaign ID: 0ec4a15c90
#   Fetching report 733 of 2160 for campaign ID: e6bdfa1162
#   Fetching report 734 of 2160 for campaign ID: 6598126a95
#   Fetching report 735 of 2160 for campaign ID: 6c21d99271
#   Fetching report 736 of 2160 for campaign ID: 32c4a0fbf4
#   Fetching report 737 of 2160 for campaign ID: f59ab3b05c
#   Fetching report 738 of 2160 for campaign ID: d0a2176576
#   Fetching report 739 of 2160 for campaign ID: d9fd98d7a4
#   Fetching report 740 of 2160 for campaign ID: f3e9e181be
#   Fetching report 741 of 2160 for campaign ID: 8f80852774
#   Fetching report 742 of 2160 for campaign ID: fea989e0c3
#   Fetching report 743 of 2160 for campaign ID: 6c27a90a8b
#   Fetching report 744 of 2160 for campaign ID: 2fd565c4fc
#   Fetching report 745 of 2160 for campaign ID: 342823e323
#   Fetching report 746 of 2160 for campaign ID: b2d780475c
#   Fetching report 747 of 2160 for campaign ID: cfe42518ca
#   Fetching report 748 of 2160 for campaign ID: 8a212fed92
#   Fetching report 749 of 2160 for campaign ID: f8c8d559a8
#   Fetching report 750 of 2160 for campaign ID: d840a92b3d
#   Fetching report 751 of 2160 for campaign ID: 1c40c27e10
#   Fetching report 752 of 2160 for campaign ID: 06e291fef3
#   Fetching report 753 of 2160 for campaign ID: 2f781f0a98
#   Fetching report 754 of 2160 for campaign ID: c84395ff2b
#   Fetching report 755 of 2160 for campaign ID: 9d663e6087
#   Fetching report 756 of 2160 for campaign ID: 9bc1f51b3b
#   Fetching report 757 of 2160 for campaign ID: 8e8809c078
#   Fetching report 758 of 2160 for campaign ID: 8e0a7fa70b
#   Fetching report 759 of 2160 for campaign ID: 198c6351ba
#   Fetching report 760 of 2160 for campaign ID: edd575a8ea
#   Fetching report 761 of 2160 for campaign ID: 0f99607ceb
#   Fetching report 762 of 2160 for campaign ID: acd0f53aab
#   Fetching report 763 of 2160 for campaign ID: 6952c9486e
#   Fetching report 764 of 2160 for campaign ID: 7b4404b404
#   Fetching report 765 of 2160 for campaign ID: 2546ec8348
#   Fetching report 766 of 2160 for campaign ID: aa08c3b6ea
#   Fetching report 767 of 2160 for campaign ID: 56251342e9
#   Fetching report 768 of 2160 for campaign ID: 1f70b6f2c0
#   Fetching report 769 of 2160 for campaign ID: c18be380a6
#   Fetching report 770 of 2160 for campaign ID: f8413008a5
#   Fetching report 771 of 2160 for campaign ID: 82eab126e3
#   Fetching report 772 of 2160 for campaign ID: 455e5c715b
#   Fetching report 773 of 2160 for campaign ID: f2ba312c2a
#   Fetching report 774 of 2160 for campaign ID: bcdfa82138
#   Fetching report 775 of 2160 for campaign ID: 6ca1b1cd93
#   Fetching report 776 of 2160 for campaign ID: b384f54ea6
#   Fetching report 777 of 2160 for campaign ID: 0bc69550af
#   Fetching report 778 of 2160 for campaign ID: e8fa31c7ae
#   Fetching report 779 of 2160 for campaign ID: 707c78888a
#   Fetching report 780 of 2160 for campaign ID: ad8a4e0ec5
#   Fetching report 781 of 2160 for campaign ID: c26a28682d
#   Fetching report 782 of 2160 for campaign ID: 8adba20c3c
#   Fetching report 783 of 2160 for campaign ID: b4593f534a
#   Fetching report 784 of 2160 for campaign ID: 645e22bf10
#   Fetching report 785 of 2160 for campaign ID: 9417a1df2d
#   Fetching report 786 of 2160 for campaign ID: f53cb7423e
#   Fetching report 787 of 2160 for campaign ID: 930a3b22bd
#   Fetching report 788 of 2160 for campaign ID: f796d3cd6c
#   Fetching report 789 of 2160 for campaign ID: 1573a9daa6
#   Fetching report 790 of 2160 for campaign ID: fb3b360d53
#   Fetching report 791 of 2160 for campaign ID: c8f036a2dc
#   Fetching report 792 of 2160 for campaign ID: 868887b2ca
#   Fetching report 793 of 2160 for campaign ID: 06a7df1412
#   Fetching report 794 of 2160 for campaign ID: 46d7ed2544
#   Fetching report 795 of 2160 for campaign ID: 66a09dfcc5
#   Fetching report 796 of 2160 for campaign ID: ac09dae05d
#   Fetching report 797 of 2160 for campaign ID: 943911c5ec
#   Fetching report 798 of 2160 for campaign ID: c5da7cc5f7
#   Fetching report 799 of 2160 for campaign ID: 72dc35ee07
#   Fetching report 800 of 2160 for campaign ID: f8a996ecff
#   Fetching report 801 of 2160 for campaign ID: 94ae037b18
#   Fetching report 802 of 2160 for campaign ID: 26d9e6c47a
#   Fetching report 803 of 2160 for campaign ID: c765ccc0da
#   Fetching report 804 of 2160 for campaign ID: ba1ff4727a
#   Fetching report 805 of 2160 for campaign ID: be128a9deb
#   Fetching report 806 of 2160 for campaign ID: 0db09503b0
#   Fetching report 807 of 2160 for campaign ID: d347e9a2f4
#   Fetching report 808 of 2160 for campaign ID: 9a700b2e6b
#   Fetching report 809 of 2160 for campaign ID: 7fe71e43c8
#   Fetching report 810 of 2160 for campaign ID: 91307e83c1
#   Fetching report 811 of 2160 for campaign ID: 9976509c46
#   Fetching report 812 of 2160 for campaign ID: 6703f99070
#   Fetching report 813 of 2160 for campaign ID: 38bdf42c61
#   Fetching report 814 of 2160 for campaign ID: 6fb8428a9c
#   Fetching report 815 of 2160 for campaign ID: 18838942a1
#   Fetching report 816 of 2160 for campaign ID: 993bbb75ae
#   Fetching report 817 of 2160 for campaign ID: 65406f1885
#   Fetching report 818 of 2160 for campaign ID: 80ddd095e4
#   Fetching report 819 of 2160 for campaign ID: 2b7804aadc
#   Fetching report 820 of 2160 for campaign ID: a26faaf48b
#   Fetching report 821 of 2160 for campaign ID: 7146048255
#   Fetching report 822 of 2160 for campaign ID: 67de71024b
#   Fetching report 823 of 2160 for campaign ID: 33eab3a864
#   Fetching report 824 of 2160 for campaign ID: aa1811c5cb
# ...
#   Fetching report 1894 of 2160 for campaign ID: edb0e2b23a
#   Fetching report 1895 of 2160 for campaign ID: 048122f045
#   Fetching report 1896 of 2160 for campaign ID: 702ae3f158
#   Fetching report 1897 of 2160 for campaign ID: 6db56a7b6f
#   Fetching report 1898 of 2160 for campaign ID: 3694066283
#   Fetching report 1899 of 2160 for campaign ID: ebeff7553a
#   Fetching report 1900 of 2160 for campaign ID: de062158f4
#   Fetching report 1901 of 2160 for campaign ID: 4ecd34b18f
#   Fetching report 1902 of 2160 for campaign ID: 6589885a74
#   Fetching report 1903 of 2160 for campaign ID: 082e66f4fa
#   Fetching report 1904 of 2160 for campaign ID: b60a0c8440
#   Fetching report 1905 of 2160 for campaign ID: 5b26131855
#   Fetching report 1906 of 2160 for campaign ID: 49ef85b04c
#   Fetching report 1907 of 2160 for campaign ID: 2fe813af27
#   Fetching report 1908 of 2160 for campaign ID: 7d0ea53a89
#   Fetching report 1909 of 2160 for campaign ID: c16664e1f8
#   Fetching report 1910 of 2160 for campaign ID: 32f274661a
#   Fetching report 1911 of 2160 for campaign ID: bf5bc9ebec
#   Fetching report 1912 of 2160 for campaign ID: c01afed058
#   Fetching report 1913 of 2160 for campaign ID: 222c8069b3
#   Fetching report 1914 of 2160 for campaign ID: 1a9622f98e
#   Fetching report 1915 of 2160 for campaign ID: 1b4cdfafef
#   Fetching report 1916 of 2160 for campaign ID: 909b198113
#   Fetching report 1917 of 2160 for campaign ID: e31a674d75
#   Fetching report 1918 of 2160 for campaign ID: b38d33ce5c
#   Fetching report 1919 of 2160 for campaign ID: 36af48ef16
#   Fetching report 1920 of 2160 for campaign ID: 840d0aa8f0
#   Fetching report 1921 of 2160 for campaign ID: 13e5967f5c
#   Fetching report 1922 of 2160 for campaign ID: 3379f0053d
#   Fetching report 1923 of 2160 for campaign ID: 8138037d15
#   Fetching report 1924 of 2160 for campaign ID: 7f4345ead6
#   Fetching report 1925 of 2160 for campaign ID: 25b6c5ef4b
#   Fetching report 1926 of 2160 for campaign ID: 935d948960
#   Fetching report 1927 of 2160 for campaign ID: e9bdfe32ab
#   Fetching report 1928 of 2160 for campaign ID: 490ccd0db3
#   Fetching report 1929 of 2160 for campaign ID: ba17aafa72
#   Fetching report 1930 of 2160 for campaign ID: c277ff83bd
#   Fetching report 1931 of 2160 for campaign ID: 25a845c5fc
#   Fetching report 1932 of 2160 for campaign ID: 983dc8c2c0
#   Fetching report 1933 of 2160 for campaign ID: be3018f910
#   Fetching report 1934 of 2160 for campaign ID: 3bb5d1c9b3
#   Fetching report 1935 of 2160 for campaign ID: 90a0521070
#   Fetching report 1936 of 2160 for campaign ID: bc47bab3b1
#   Fetching report 1937 of 2160 for campaign ID: 78dbe3c15e
#   Fetching report 1938 of 2160 for campaign ID: b58ec40de0
#   Fetching report 1939 of 2160 for campaign ID: feaaaacc3f
#   Fetching report 1940 of 2160 for campaign ID: 9ff8e40148
#   Fetching report 1941 of 2160 for campaign ID: 7fe66aee5b
#   Fetching report 1942 of 2160 for campaign ID: 3ad37f6747
#   Fetching report 1943 of 2160 for campaign ID: 8533cbdc02
#   Fetching report 1944 of 2160 for campaign ID: 5b18dd7122
#   Fetching report 1945 of 2160 for campaign ID: 4f50ea0682
#   Fetching report 1946 of 2160 for campaign ID: ac90fe31c6
#   Fetching report 1947 of 2160 for campaign ID: 3d47b9d369
#   Fetching report 1948 of 2160 for campaign ID: 297a95c3d9
#   Fetching report 1949 of 2160 for campaign ID: 2543a045c5
#   Fetching report 1950 of 2160 for campaign ID: 2396e83ea3
#   Fetching report 1951 of 2160 for campaign ID: 5f0a9a3cbe
#   Fetching report 1952 of 2160 for campaign ID: 61d2db4e7d
#   Fetching report 1953 of 2160 for campaign ID: f2c16f443c
#   Fetching report 1954 of 2160 for campaign ID: 571a01d247
#   Fetching report 1955 of 2160 for campaign ID: 821be2e39a
#   Fetching report 1956 of 2160 for campaign ID: 5451f1e53f
#   Fetching report 1957 of 2160 for campaign ID: 05875566f2
#   Fetching report 1958 of 2160 for campaign ID: d12cf2b9d6
#   Fetching report 1959 of 2160 for campaign ID: a87d85375b
#   Fetching report 1960 of 2160 for campaign ID: ba54f7b8be
#   Fetching report 1961 of 2160 for campaign ID: 963a941591
#   Fetching report 1962 of 2160 for campaign ID: 4448cb402b
#   Fetching report 1963 of 2160 for campaign ID: 665f199ba4
#   Fetching report 1964 of 2160 for campaign ID: 4ded83b0ae
#   Fetching report 1965 of 2160 for campaign ID: e7d3969fbb
#   Fetching report 1966 of 2160 for campaign ID: 8a5174d8b9
#   Fetching report 1967 of 2160 for campaign ID: 3e2f2a7061
#   Fetching report 1968 of 2160 for campaign ID: 3c0e11aef2
#   Fetching report 1969 of 2160 for campaign ID: 89885d6486
#   Fetching report 1970 of 2160 for campaign ID: 9b35be0f18
#   Fetching report 1971 of 2160 for campaign ID: 3a59e400db
#   Fetching report 1972 of 2160 for campaign ID: 7e6ce4ff6c
#   Fetching report 1973 of 2160 for campaign ID: 5bd98cf93d
#   Fetching report 1974 of 2160 for campaign ID: 788d1894b9
#   Fetching report 1975 of 2160 for campaign ID: 26fb8f25a5
#   Fetching report 1976 of 2160 for campaign ID: d2b350e100
#   Fetching report 1977 of 2160 for campaign ID: a7ea9991fb
#   Fetching report 1978 of 2160 for campaign ID: 57915e665a
#   Fetching report 1979 of 2160 for campaign ID: 557240d8e1
#   Fetching report 1980 of 2160 for campaign ID: ec45a38f0b
#   Fetching report 1981 of 2160 for campaign ID: 9a995bbb0b
#   Fetching report 1982 of 2160 for campaign ID: 618a093909
#   Fetching report 1983 of 2160 for campaign ID: 1fdd9246fe
#   Fetching report 1984 of 2160 for campaign ID: 232235cd08
#   Fetching report 1985 of 2160 for campaign ID: bfdcc3132a
#   Fetching report 1986 of 2160 for campaign ID: 6d0aa7585d
#   Fetching report 1987 of 2160 for campaign ID: 06b379d8d1
#   Fetching report 1988 of 2160 for campaign ID: 4d62f560f8
#   Fetching report 1989 of 2160 for campaign ID: 61e5643bc9
#   Fetching report 1990 of 2160 for campaign ID: e287e2e260
#   Fetching report 1991 of 2160 for campaign ID: 1a6287c27f
#   Fetching report 1992 of 2160 for campaign ID: f20084b8dd
#   Fetching report 1993 of 2160 for campaign ID: 1dea8809e3
#   Fetching report 1994 of 2160 for campaign ID: 56c2b8a5bd
#   Fetching report 1995 of 2160 for campaign ID: 8a7b8378b2
#   Fetching report 1996 of 2160 for campaign ID: 7d3db2765e
#   Fetching report 1997 of 2160 for campaign ID: 6a6147e573
#   Fetching report 1998 of 2160 for campaign ID: 3e122c4edb
#   Fetching report 1999 of 2160 for campaign ID: c66b050380
#   Fetching report 2000 of 2160 for campaign ID: c07267b3bb
#   Fetching report 2001 of 2160 for campaign ID: 976ea398a2
#   Fetching report 2002 of 2160 for campaign ID: 33decc558c
#   Fetching report 2003 of 2160 for campaign ID: bff4237d2a
#   Fetching report 2004 of 2160 for campaign ID: df66b0d709
#   Fetching report 2005 of 2160 for campaign ID: 6cdbf12266
#   Fetching report 2006 of 2160 for campaign ID: 5008e6e231
#   Fetching report 2007 of 2160 for campaign ID: 7ebdd1ad2e
#   Fetching report 2008 of 2160 for campaign ID: 20adb3d4c9
#   Fetching report 2009 of 2160 for campaign ID: 67631a1686
#   Fetching report 2010 of 2160 for campaign ID: 918b5bbf2b
#   Fetching report 2011 of 2160 for campaign ID: c7dcc72f88
#   Fetching report 2012 of 2160 for campaign ID: 181b1bfea2
#   Fetching report 2013 of 2160 for campaign ID: b8dcb2a14d
#   Fetching report 2014 of 2160 for campaign ID: 224e6086b2
#   Fetching report 2015 of 2160 for campaign ID: 1587014acb
#   Fetching report 2016 of 2160 for campaign ID: 886785688a
#   Fetching report 2017 of 2160 for campaign ID: 7793848629
#   Fetching report 2018 of 2160 for campaign ID: 3076e8843e
#   Fetching report 2019 of 2160 for campaign ID: d6e3e2f3d7
#   Fetching report 2020 of 2160 for campaign ID: 20e0d66661
#   Fetching report 2021 of 2160 for campaign ID: 88c4d24746
#   Fetching report 2022 of 2160 for campaign ID: 2e6658fb62
#   Fetching report 2023 of 2160 for campaign ID: 3305f37473
#   Fetching report 2024 of 2160 for campaign ID: b55fb647a5
#   Fetching report 2025 of 2160 for campaign ID: e5929b7f81
#   Fetching report 2026 of 2160 for campaign ID: e9c9c2a684
#   Fetching report 2027 of 2160 for campaign ID: 109648a253
#   Fetching report 2028 of 2160 for campaign ID: 6bc94dff51
#   Fetching report 2029 of 2160 for campaign ID: c9ca501833
#   Fetching report 2030 of 2160 for campaign ID: e78e6b54f6
#   Fetching report 2031 of 2160 for campaign ID: c657483f7e
#   Fetching report 2032 of 2160 for campaign ID: e478859650
#   Fetching report 2033 of 2160 for campaign ID: 7d1cee3fe7
#   Fetching report 2034 of 2160 for campaign ID: eb9679f9b9
#   Fetching report 2035 of 2160 for campaign ID: 90ba1f33e1
#   Fetching report 2036 of 2160 for campaign ID: 93b452d8df
#   Fetching report 2037 of 2160 for campaign ID: e44ff0d687
#   Fetching report 2038 of 2160 for campaign ID: 46c7a51b49
#   Fetching report 2039 of 2160 for campaign ID: 88f815b24e
#   Fetching report 2040 of 2160 for campaign ID: c383675cc1
#   Fetching report 2041 of 2160 for campaign ID: 8d602c6d8a
#   Fetching report 2042 of 2160 for campaign ID: 8a9f0e6ce8
#   Fetching report 2043 of 2160 for campaign ID: 45794c4b50
#   Fetching report 2044 of 2160 for campaign ID: ad88aee1a6
#   Fetching report 2045 of 2160 for campaign ID: fbcf1f925c
#   Fetching report 2046 of 2160 for campaign ID: 3d3e32d458
#   Fetching report 2047 of 2160 for campaign ID: 1cb9c4aee4
#   Fetching report 2048 of 2160 for campaign ID: 695e9cce6b
#   Fetching report 2049 of 2160 for campaign ID: 48c749be82
#   Fetching report 2050 of 2160 for campaign ID: ae6a5a63aa
#   Fetching report 2051 of 2160 for campaign ID: 2428b74075
#   Fetching report 2052 of 2160 for campaign ID: 37cdd80a0f
#   Fetching report 2053 of 2160 for campaign ID: dd85db49c9
#   Fetching report 2054 of 2160 for campaign ID: 1dd5c1b5a9
#   Fetching report 2055 of 2160 for campaign ID: b9d38888bc
#   Fetching report 2056 of 2160 for campaign ID: 5e853c4abb
#   Fetching report 2057 of 2160 for campaign ID: 8c646cc4ef
#   Fetching report 2058 of 2160 for campaign ID: 65d450c372
#   Fetching report 2059 of 2160 for campaign ID: 77a2afb212
#   Fetching report 2060 of 2160 for campaign ID: 1abda1f774
#   Fetching report 2061 of 2160 for campaign ID: 41acb90e31
#   Fetching report 2062 of 2160 for campaign ID: a45612a7c1
#   Fetching report 2063 of 2160 for campaign ID: f455b397eb
#   Fetching report 2064 of 2160 for campaign ID: e3bc996dcf
#   Fetching report 2065 of 2160 for campaign ID: c56262b7a7
#   Fetching report 2066 of 2160 for campaign ID: 86bd8185cb
#   Fetching report 2067 of 2160 for campaign ID: 76bb61f693
#   Fetching report 2068 of 2160 for campaign ID: c7196df6e1
#   Fetching report 2069 of 2160 for campaign ID: 8d3d6be748
#   Fetching report 2070 of 2160 for campaign ID: 51b3cc9d87
#   Fetching report 2071 of 2160 for campaign ID: 4d0cd83232
#   Fetching report 2072 of 2160 for campaign ID: 625ac578a1
#   Fetching report 2073 of 2160 for campaign ID: 8e23768fbc
#   Fetching report 2074 of 2160 for campaign ID: b7ec68da9c
#   Fetching report 2075 of 2160 for campaign ID: 5fccff49e9
#   Fetching report 2076 of 2160 for campaign ID: 61b6c49fcd
#   Fetching report 2077 of 2160 for campaign ID: 4f02de04fc
#   Fetching report 2078 of 2160 for campaign ID: 8e9314831f
#   Fetching report 2079 of 2160 for campaign ID: c0c2845e08
#   Fetching report 2080 of 2160 for campaign ID: 65227c8ce4
#   Fetching report 2081 of 2160 for campaign ID: 8bfd9e48bd
#   Fetching report 2082 of 2160 for campaign ID: f8852865b0
#   Fetching report 2083 of 2160 for campaign ID: d8a8fb2a7c
#   Fetching report 2084 of 2160 for campaign ID: 6b0ef5e2b3
#   Fetching report 2085 of 2160 for campaign ID: 0265b555c5
#   Fetching report 2086 of 2160 for campaign ID: 640d626978
#   Fetching report 2087 of 2160 for campaign ID: 6e214beff4
#   Fetching report 2088 of 2160 for campaign ID: 1a8bc0ec0e
#   Fetching report 2089 of 2160 for campaign ID: 15f2b5b2b8
#   Fetching report 2090 of 2160 for campaign ID: f6e8f126a9
#   Fetching report 2091 of 2160 for campaign ID: 57bd1b2480
#   Fetching report 2092 of 2160 for campaign ID: 8d82e88639
#   Fetching report 2093 of 2160 for campaign ID: fec738844f
#   Fetching report 2094 of 2160 for campaign ID: a871c6806d
#   Fetching report 2095 of 2160 for campaign ID: de05459f2d
#   Fetching report 2096 of 2160 for campaign ID: 338e7d3a31
#   Fetching report 2097 of 2160 for campaign ID: ae08c1cf1c
#   Fetching report 2098 of 2160 for campaign ID: 6407513bec
#   Fetching report 2099 of 2160 for campaign ID: dc2311686f
#   Fetching report 2100 of 2160 for campaign ID: c5fb8877fa
#   Fetching report 2101 of 2160 for campaign ID: 8ad4a9ac3b
#   Fetching report 2102 of 2160 for campaign ID: c2f60103fb
#   Fetching report 2103 of 2160 for campaign ID: ed92810ce5
#   Fetching report 2104 of 2160 for campaign ID: 2982c57db6
#   Fetching report 2105 of 2160 for campaign ID: ccffd1cca5
#   Fetching report 2106 of 2160 for campaign ID: 0e2e3997cb
#   Fetching report 2107 of 2160 for campaign ID: d35988c674
#   Fetching report 2108 of 2160 for campaign ID: 459ce491c4
#   Fetching report 2109 of 2160 for campaign ID: b91cc6c882
#   Fetching report 2110 of 2160 for campaign ID: d7035d4c58
#   Fetching report 2111 of 2160 for campaign ID: 34efa6bf20
#   Fetching report 2112 of 2160 for campaign ID: 44ac90b999
#   Fetching report 2113 of 2160 for campaign ID: b5a0236bf1
#   Fetching report 2114 of 2160 for campaign ID: 12a8dfd591
#   Fetching report 2115 of 2160 for campaign ID: 4d27877762
#   Fetching report 2116 of 2160 for campaign ID: e4b4ad00c3
#   Fetching report 2117 of 2160 for campaign ID: 0d9989ea05
#   Fetching report 2118 of 2160 for campaign ID: 840789731a
#   Fetching report 2119 of 2160 for campaign ID: c1a0b84891
#   Fetching report 2120 of 2160 for campaign ID: 6291bfcfb2
#   Fetching report 2121 of 2160 for campaign ID: 2e936c0a05
#   Fetching report 2122 of 2160 for campaign ID: e499285a6d
#   Fetching report 2123 of 2160 for campaign ID: 2d5a363abe
#   Fetching report 2124 of 2160 for campaign ID: 0945dc7de8
#   Fetching report 2125 of 2160 for campaign ID: 4a70c76e3d
#   Fetching report 2126 of 2160 for campaign ID: ed0a40ff2f
#   Fetching report 2127 of 2160 for campaign ID: 320dd582ed
#   Fetching report 2128 of 2160 for campaign ID: 1b2dbcdab6
#   Fetching report 2129 of 2160 for campaign ID: a97b8c5d93
#   Fetching report 2130 of 2160 for campaign ID: c7c3e9a8c0
#   Fetching report 2131 of 2160 for campaign ID: a73375501a
#   Fetching report 2132 of 2160 for campaign ID: 6fd6bb96e6
#   Fetching report 2133 of 2160 for campaign ID: 090c02bdac
#   Fetching report 2134 of 2160 for campaign ID: 9084719e52
#   Fetching report 2135 of 2160 for campaign ID: b5e829d04c
#   Fetching report 2136 of 2160 for campaign ID: 72e491a841
#   Fetching report 2137 of 2160 for campaign ID: 7b6ba1bf87
#   Fetching report 2138 of 2160 for campaign ID: 094e3b09f8
#   Fetching report 2139 of 2160 for campaign ID: 905c39882a
#   Fetching report 2140 of 2160 for campaign ID: 5edffcbcb9
#   Fetching report 2141 of 2160 for campaign ID: de2dbdd829
#   Fetching report 2142 of 2160 for campaign ID: a83dd1d63a
#   Fetching report 2143 of 2160 for campaign ID: 3ec85352c2
#   Fetching report 2144 of 2160 for campaign ID: 999ae17c8c
#   Fetching report 2145 of 2160 for campaign ID: d04e7bdf61
#   Fetching report 2146 of 2160 for campaign ID: 5348d6a936
#   Fetching report 2147 of 2160 for campaign ID: abad9a8a97
#   Fetching report 2148 of 2160 for campaign ID: 087d14be20
#   Fetching report 2149 of 2160 for campaign ID: e42486de1d
#   Fetching report 2150 of 2160 for campaign ID: 7614b153d2
#   Fetching report 2151 of 2160 for campaign ID: d9296c195f
#   Fetching report 2152 of 2160 for campaign ID: a7f65bd578
#   Fetching report 2153 of 2160 for campaign ID: 92fd42686c
#   Fetching report 2154 of 2160 for campaign ID: 88978c1761
#   Fetching report 2155 of 2160 for campaign ID: acf6822e8e
#   Fetching report 2156 of 2160 for campaign ID: ba88ab8ca4
#   Fetching report 2157 of 2160 for campaign ID: 64964170fa
#   Fetching report 2158 of 2160 for campaign ID: bf273cb6e0
#   Fetching report 2159 of 2160 for campaign ID: 27a0a666e3
#   Fetching report 2160 of 2160 for campaign ID: 5fadb36fef
#
# --- Extraction Complete: Found 2160 total reports. ---
#
# Initiating load job for 2160 records into mis581-capstone-data.raw_data.peer2_reports_raw...
# SUCCESS: BigQuery load job finished. Loaded 2160 rows.
